# %% [markdown]
# # Lab 8
#
# **Lecture**: Deep Learning (Prof. Dr. David Rügamer, Emanuel Sommer)
#
# ## Imports

# %%
import random
import shutil
import urllib.request
from functools import reduce, partial
from math import ceil
from pathlib import Path
from typing import Optional, Callable

import matplotlib.pyplot as plt
import torch
from PIL import Image
from matplotlib_inline.backend_inline import set_matplotlib_formats
from torch import nn, Tensor
from torch.optim import Adam, Optimizer
from torch.utils.data import DataLoader, Dataset
from torchsummary import summary
from torchvision import transforms
from torchvision.models import vgg16

set_matplotlib_formats('png', 'pdf')

# %% [markdown]
# ## Exercise 1
# NB: it is impractical to do this exercise on your laptop, even if you have a GPU.
# You are advised to work on
# [Google Colab](https://colab.research.google.com).
#
# In this exercise we would like to build a classification system for 120 different breeds
# of dogs, based on commonplace pictures. The data is available on
# [Kaggle](https://www.kaggle.com/c/dog-breed-identification/data) (permanent, requires an
# account) or [Dropbox](https://www.dropbox.com/s/l7b7l5fjwwj6ad2/dog-breed-identification.zip?dl=0)
# (temporary, no login needed).
# Download it and unzip it, then put the contents in a folder named `.data/DOGBREED`.
# Otherwise, execute the code below.

# %%
# If you have problems downloading from python, try from a browser.
url = 'https://www.dropbox.com/s/l7b7l5fjwwj6ad2/dog-breed-identification.zip?dl=1'
data_root = '.data'
dataset_dir = Path(data_root, 'DOGBREED')
file_name = 'dog-breed-identification.zip'
file_path = Path(data_root, file_name)

if not dataset_dir.exists():
    Path(data_root).mkdir(exist_ok=True)
    urllib.request.urlretrieve(url, file_path)
    shutil.unpack_archive(file_path, dataset_dir)
    file_path.unlink()

# %% [markdown]
# This dataset is composed of 10222 pictures in different resolutions and aspect rations.
# The smallest classes are Briad and Eskimo dog with only 66 images each, whereas the
# biggest class is the Scottish deerhound with 126 images.
#
# Here are some sample images along with the relative label:

# %%
with open(Path(dataset_dir, 'labels.csv')) as file:
    label_list = file.readlines()

label_list = [label_entry.strip().split(sep=',') for label_entry in label_list][1:]
print(label_list[:3])
# Out:
# [['000bec180eb18c7604dcecc8fe0dba07', 'boston_bull'], ['001513dfcb2ffafc82cccf4d8bbaba97', 'dingo'], ['001cdf01b096e06d78e9e5112d419397', 'pekinese']]

# %%
_, axs = plt.subplots(5, 5, figsize=(10, 10))
axs = axs.flatten()
for ax in axs:
    rand_file, rand_label = tuple(label_list[random.randint(0, len(label_list))])
    img = Image.open(Path(dataset_dir, 'train', rand_file + '.jpg'))
    ax.imshow(img)
    ax.set_title(rand_label)
    ax.axis('off')
plt.show()

# %% [markdown]
# This is a challenging problem since there are many classes and only few instances per
# class. Moreover, the images contain a lot of details that do not help to identify the
# dogs, but allow a network to easily memorize the data. We will first try to naively
# approach the problem and directly train a CNN on this dataset.
# After convincing ourselves that this is not going to work, we will use a pre-trained
# VGG16 (i.e., trained successfully on some other dataset) and fine-tune it to our data.
#
# But first, we do a bit of data organizing to reserve some images for a validation subset.
# Afterwards, we will create a custom `Dataset` that conveniently loads images on the fly
# during our training procedure.
#
# We will also convert our labels to integers and create a dict with the reverse mapping.

# %%
# Shuffle list of all keys and labels
random.shuffle(label_list)
val_size = len(label_list) // 5

# Split in training and validation sets
train_label_list = label_list[val_size:]
val_label_list = label_list[:val_size]

# Extract keys and labels
train_keys, train_labels = zip(*train_label_list)
val_keys, val_labels = zip(*val_label_list)

# Get all unique classes
unique_classes = set([label_entry[1] for label_entry in label_list])
print('Number of classes: {}'.format(len(unique_classes)))

# Create class mappings
num_to_class_mapping = {i: class_label for i, class_label in enumerate(unique_classes)}
class_to_num_mapping = {class_label: i for i, class_label in enumerate(unique_classes)}

# Convert string labels to integers
train_labels = [class_to_num_mapping[label] for label in train_labels]
val_labels = [class_to_num_mapping[label] for label in val_labels]
# Out:
# Number of classes: 120

# %%
class DogBreedDataset(Dataset):
    def __init__(self,
                 keys: list[str],
                 labels: [int],
                 img_root: Optional[Path] = None,
                 transform: Optional[Callable] = None
                 ):
        """
        Initialize a dog breed dataset.

        :param keys: list of identifiers for the images.
        :param labels: list of labels for the identifiers.
        :param img_root: Path pointing to the image directory.
        :param transform: Transformation to apply on loaded image.
        """

        self.keys = keys
        self.labels = labels
        self.transform = transform

        if img_root is None:
            self.img_root = Path('.data', 'DOGBREED', 'train')
        else:
            self.img_root = img_root


    def __len__(self) -> int:
        return len(self.keys)

    @property
    def shape(self) -> tuple:
        return self[0][0].shape

    def __getitem__(self, idx: int) -> tuple[Tensor, Tensor]:
        key = self.keys[idx]
        img = (
            Image.open(Path(self.img_root, key + '.jpg'))
        )

        if self.transform is not None:
            img = self.transform(img)

        y = (
            torch.tensor(self.labels[idx], dtype=torch.long)
        )


        return img, y

# %% [markdown]
# ### Data preparation
# As this dataset is fairly small, we can generate more synthetic images by applying random
# transformations to the images we have.
# You might have noticed that our `DogBreedDataset` already takes `transform` as an argument,
# where we will pass some functions, that transform our images during training.
# Everytime a new batch of data is requested, the augmentations are randomly applied on-the-fly.
# This saves a lot of memory, at the price of larger computational resources needed.
#
# This technique is called _data augmentation_,
# and it can greatly help in reducing overfitting on small datasets.
#
# For this task we can use the `transforms` module of `torchvision` (check the docs
# [here](https://pytorch.org/vision/stable/transforms.html)). To chain multiple transformations,
# we use `Compose`.
#
# We now want to randomly perform the following transformations to each image:
#
#  - Flip horizontally
#  - Rotation of at most 30 degrees
#  - Change brightness, contrast and saturation (`ColorJitter`)
#  - Change perspective (`RandomPerspective`)
#  - Resize to $224 \times 224$
#  - Convert from PIL image to a tensor with a range 0 to 1 (now 0 to 255).
#
# We do not use random augmentation for the validation images except for centering and
# scaling. Why?

# %%
# Resizing to a square with varying aspect ratios per image can be a bit tricky.
# We define a small custom transformation, where we will pad the input to a square shape
# and then do the resizing.
# More info: https://discuss.pytorch.org/t/how-to-resize-and-pad-in-a-torchvision-transforms-compose/71850
class ResizeToSquare:
    def __init__(self, size: int):
        self.resize_transform = transforms.Resize(size)

    def __call__(self, img: Image) -> Image:
        img = self._do_square_padding(img)
        return self.resize_transform(img)

    @staticmethod
    def _do_square_padding(img: Image) -> Image:
        max_wh = max(img.size)
        p_left, p_top = [(max_wh - s) // 2 for s in img.size]
        p_right, p_bottom = [max_wh - (s+pad) for s, pad in zip(img.size, [p_left, p_top])]
        padding = (p_left, p_top, p_right, p_bottom)
        return transforms.functional.pad(img, padding, 0, 'constant')

train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(degrees=30),
    transforms.ColorJitter(
        brightness=0.5,
        saturation=0.5,
        contrast=0.5,
        hue=0.2
    ),
    transforms.RandomPerspective(),
    ResizeToSquare(size=224),
    transforms.ToTensor()
])

val_transforms = transforms.Compose([
    ResizeToSquare(size=224),
    transforms.ToTensor()
])

# %% [markdown]
# We can now finally create our `DogBreedDataset` objects:

# %%
train_dataset = DogBreedDataset(
    keys=train_keys,
    labels=train_labels,
    transform=train_transforms
)

val_dataset = DogBreedDataset(
    keys=val_keys,
    labels=val_labels,
    transform=val_transforms
)

# %% [markdown]
# Here are some examples of how the augmented images look:

# %%
_, axs = plt.subplots(5, 5, figsize=(10, 10))
axs = axs.flatten()
for ax in axs:
    img, label = train_dataset[random.randint(0, len(train_dataset))]
    ax.imshow(img.permute(1, 2, 0))
    ax.set_title(num_to_class_mapping[int(label)])
    ax.axis('off')
plt.show()

# %% [markdown]
# ### Define a Network
# After preparing the data we define a network architecture.
# There are a lot of possible architectures. A good start might be a slightly smaller
# version of the famous VGG16 architecture. It consists of 4 blocks of 2 convolutional
# layers followed by one max pooling step, then two fully connected layers of size 512
# are used, for a total of around 5 million weight parameters.
#
# Global average pooling is used instead of flattening to reduce the number of parameters
# of the network. It takes the average of every input channel, so that a tensor of shape
# 14x14x512 results in a vector of 512 elements, each of which is the average of the
# corresponding 14x14 slice.
#
# Also let's define our device. The exercise will run without a GPU but it is probably
# not feasible as computation on CPU would be magnitudes slower.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = nn.Sequential(
   # Block 1
    nn.Conv2d(in_channels=3, out_channels=64, kernel_size=(3, 3), padding=1),
    nn.ReLU(),
    nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3, 3), padding=1),
    nn.ReLU(),
    nn.MaxPool2d(2),

    # Block 2
    nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3, 3), padding=1),
    nn.ReLU(),
    nn.Conv2d(in_channels=128, out_channels=128, kernel_size=(3, 3), padding=1),
    nn.ReLU(),
    nn.MaxPool2d(2),

    # Block 3
    nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3, 3), padding=1),
    nn.ReLU(),
    nn.Conv2d(in_channels=256, out_channels=256, kernel_size=(3, 3), padding=1),
    nn.ReLU(),
    nn.MaxPool2d(2),

    # Block 4
    nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3, 3), padding=1),
    nn.ReLU(),
    nn.Conv2d(in_channels=512, out_channels=512, kernel_size=(3, 3), padding=1),
    nn.ReLU(),
    nn.MaxPool2d(2),

    # Flatten by global averaging.
    nn.AdaptiveAvgPool2d((1, 1)),
    nn.Flatten(),
    nn.Linear(in_features=512, out_features=512),
    nn.ReLU(),
    nn.Linear(in_features=512, out_features=512),
    nn.ReLU(),

    # Output for 120 classes.
    nn.Linear(in_features=512, out_features=120),
).to(device)

# %%
summary(model, input_size=(3, 224, 224), device=str(device))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#         MaxPool2d-15          [-1, 256, 28, 28]               0
#            Conv2d-16          [-1, 512, 28, 28]       1,180,160
#              ReLU-17          [-1, 512, 28, 28]               0
#            Conv2d-18          [-1, 512, 28, 28]       2,359,808
#              ReLU-19          [-1, 512, 28, 28]               0
#         MaxPool2d-20          [-1, 512, 14, 14]               0
# AdaptiveAvgPool2d-21            [-1, 512, 1, 1]               0
#           Flatten-22                  [-1, 512]               0
#            Linear-23                  [-1, 512]         262,656
#              ReLU-24                  [-1, 512]               0
#            Linear-25                  [-1, 512]         262,656
#              ReLU-26                  [-1, 512]               0
#            Linear-27                  [-1, 120]          61,560
# ================================================================
# Total params: 5,272,248
# Trainable params: 5,272,248
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 195.26
# Params size (MB): 20.11
# Estimated Total Size (MB): 215.94
# ----------------------------------------------------------------

# %% [markdown]
# ### Train the network
#
# As usual, let's define an optimizer, loss function, dataloaders and training loop.

# %%
epochs = 5
batch_size = 16
num_workers = 4

loss = (
    nn.CrossEntropyLoss()
)

optimizer = (
    Adam(model.parameters())
)


train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
)

val_loader = DataLoader(
    dataset=val_dataset,
    batch_size=batch_size,
    num_workers=num_workers,
)

def train(
        model: nn.Module,
        loss: nn.Module,
        optimizer: Optimizer,
        train_loader: DataLoader,
        val_loader: DataLoader,
        epochs: int
) -> dict:
    # Intermediate results during training will be saved here.
    # This allows plotting the training progress afterwards.
    metrics: dict = {
        'train_loss': [],
        'train_acc': [],
        'val_loss': [],
        'val_acc': [],
    }

    num_train_batches = ceil(len(train_loader.dataset) / batch_size)
    num_val_batches = ceil(len(val_loader.dataset) / batch_size)

    for ep in range(1, epochs + 1):
        total_loss = 0
        num_correct = 0

        for batch_idx, (x, y) in enumerate(train_loader):
            x = x.to(device)
            y = y.to(device)

            y_hat = model(x)
            batch_loss = loss(y_hat, y)

            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            if batch_idx % 10 == 0:
                print('TRAINING BATCH:\t({:5} / {:5})\tLOSS:\t{:.3f}'
                      .format(batch_idx, num_train_batches, float(batch_loss)), end='\r')

            total_loss += float(batch_loss)
            num_correct += int(torch.sum(torch.argmax(y_hat, dim=1) == y))


        ep_train_loss = total_loss / num_train_batches
        ep_train_acc = num_correct / len(train_loader.dataset)

        # Reset counters
        total_loss = 0
        num_correct = 0

        for batch_idx, (x, y) in enumerate(val_loader):
            x = x.to(device)
            y = y.to(device)

            with torch.no_grad():
                y_hat = model(x)
                batch_loss = loss(y_hat, y)

            if batch_idx % 10 == 0:
                print('VALIDATION BATCH:\t({:5} / {:5})\tLOSS:\t{:.3f}'
                      .format(batch_idx, num_val_batches, float(batch_loss)), end='\r')

            total_loss += float(batch_loss)
            num_correct += int(torch.sum(torch.argmax(y_hat, dim=1) == y))

        ep_val_loss = total_loss / num_val_batches
        ep_val_acc = num_correct / len(val_loader.dataset)

        metrics['train_loss'].append(ep_train_loss)
        metrics['train_acc'].append(ep_train_acc)
        metrics['val_loss'].append(ep_val_loss)
        metrics['val_acc'].append(ep_val_acc)

        print('EPOCH:\t{:5}\tTRAIN LOSS:\t{:.3f}\tTRAIN ACCURACY:\t{:.3f}\tVAL LOSS:\t'
              '{:.3f}\tVAL ACCURACY:\t{:.3f}'
              .format(ep, ep_train_loss, ep_train_acc,ep_val_loss, ep_val_acc,
                      end='\r'))
    return metrics

metrics = train(model, loss, optimizer, train_loader, val_loader, epochs)
# Out:
# TRAINING BATCH:	(    0 /   512)	LOSS:	4.793
# TRAINING BATCH:	(   10 /   512)	LOSS:	4.810
# TRAINING BATCH:	(   20 /   512)	LOSS:	4.800
# TRAINING BATCH:	(   30 /   512)	LOSS:	4.791
# TRAINING BATCH:	(   40 /   512)	LOSS:	4.804
# TRAINING BATCH:	(   50 /   512)	LOSS:	4.784
# TRAINING BATCH:	(   60 /   512)	LOSS:	4.792
# TRAINING BATCH:	(   70 /   512)	LOSS:	4.805
# TRAINING BATCH:	(   80 /   512)	LOSS:	4.822
# TRAINING BATCH:	(   90 /   512)	LOSS:	4.751
# TRAINING BATCH:	(  100 /   512)	LOSS:	4.802
# TRAINING BATCH:	(  110 /   512)	LOSS:	4.771
# TRAINING BATCH:	(  120 /   512)	LOSS:	4.844
# TRAINING BATCH:	(  130 /   512)	LOSS:	4.787
# TRAINING BATCH:	(  140 /   512)	LOSS:	4.801
# TRAINING BATCH:	(  150 /   512)	LOSS:	4.765
# TRAINING BATCH:	(  160 /   512)	LOSS:	4.796
# TRAINING BATCH:	(  170 /   512)	LOSS:	4.789
# TRAINING BATCH:	(  180 /   512)	LOSS:	4.803
# TRAINING BATCH:	(  190 /   512)	LOSS:	4.789
# TRAINING BATCH:	(  200 /   512)	LOSS:	4.752
# TRAINING BATCH:	(  210 /   512)	LOSS:	4.831
# TRAINING BATCH:	(  220 /   512)	LOSS:	4.827
# TRAINING BATCH:	(  230 /   512)	LOSS:	4.808
# TRAINING BATCH:	(  240 /   512)	LOSS:	4.769
# TRAINING BATCH:	(  250 /   512)	LOSS:	4.776
# TRAINING BATCH:	(  260 /   512)	LOSS:	4.782
# TRAINING BATCH:	(  270 /   512)	LOSS:	4.734
# TRAINING BATCH:	(  280 /   512)	LOSS:	4.787
# TRAINING BATCH:	(  290 /   512)	LOSS:	4.812
# TRAINING BATCH:	(  300 /   512)	LOSS:	4.778
# TRAINING BATCH:	(  310 /   512)	LOSS:	4.802
# TRAINING BATCH:	(  320 /   512)	LOSS:	4.787
# TRAINING BATCH:	(  330 /   512)	LOSS:	4.747
# TRAINING BATCH:	(  340 /   512)	LOSS:	4.774
# TRAINING BATCH:	(  350 /   512)	LOSS:	4.793
# TRAINING BATCH:	(  360 /   512)	LOSS:	4.796
# TRAINING BATCH:	(  370 /   512)	LOSS:	4.750
# TRAINING BATCH:	(  380 /   512)	LOSS:	4.786
# TRAINING BATCH:	(  390 /   512)	LOSS:	4.793
# TRAINING BATCH:	(  400 /   512)	LOSS:	4.741
# TRAINING BATCH:	(  410 /   512)	LOSS:	4.782
# TRAINING BATCH:	(  420 /   512)	LOSS:	4.816
# TRAINING BATCH:	(  430 /   512)	LOSS:	4.783
# TRAINING BATCH:	(  440 /   512)	LOSS:	4.775
# TRAINING BATCH:	(  450 /   512)	LOSS:	4.827
# TRAINING BATCH:	(  460 /   512)	LOSS:	4.771
# TRAINING BATCH:	(  470 /   512)	LOSS:	4.794
# TRAINING BATCH:	(  480 /   512)	LOSS:	4.792
# TRAINING BATCH:	(  490 /   512)	LOSS:	4.789
# TRAINING BATCH:	(  500 /   512)	LOSS:	4.811
# TRAINING BATCH:	(  510 /   512)	LOSS:	4.791
# VALIDATION BATCH:	(    0 /   128)	LOSS:	4.790
# VALIDATION BATCH:	(   10 /   128)	LOSS:	4.775
# VALIDATION BATCH:	(   20 /   128)	LOSS:	4.800
# VALIDATION BATCH:	(   30 /   128)	LOSS:	4.817
# VALIDATION BATCH:	(   40 /   128)	LOSS:	4.781
# VALIDATION BATCH:	(   50 /   128)	LOSS:	4.767
# VALIDATION BATCH:	(   60 /   128)	LOSS:	4.782
# VALIDATION BATCH:	(   70 /   128)	LOSS:	4.782
# VALIDATION BATCH:	(   80 /   128)	LOSS:	4.777
# VALIDATION BATCH:	(   90 /   128)	LOSS:	4.801
# VALIDATION BATCH:	(  100 /   128)	LOSS:	4.791
# VALIDATION BATCH:	(  110 /   128)	LOSS:	4.768
# VALIDATION BATCH:	(  120 /   128)	LOSS:	4.778
# EPOCH:	    1	TRAIN LOSS:	4.787	TRAIN ACCURACY:	0.010	VAL LOSS:	4.785	VAL ACCURACY:	0.015
# TRAINING BATCH:	(    0 /   512)	LOSS:	4.782
# TRAINING BATCH:	(   10 /   512)	LOSS:	4.815
# TRAINING BATCH:	(   20 /   512)	LOSS:	4.808
# TRAINING BATCH:	(   30 /   512)	LOSS:	4.773
# TRAINING BATCH:	(   40 /   512)	LOSS:	4.751
# TRAINING BATCH:	(   50 /   512)	LOSS:	4.800
# TRAINING BATCH:	(   60 /   512)	LOSS:	4.795
# TRAINING BATCH:	(   70 /   512)	LOSS:	4.760
# TRAINING BATCH:	(   80 /   512)	LOSS:	4.731
# TRAINING BATCH:	(   90 /   512)	LOSS:	4.810
# TRAINING BATCH:	(  100 /   512)	LOSS:	4.719
# TRAINING BATCH:	(  110 /   512)	LOSS:	4.794
# TRAINING BATCH:	(  120 /   512)	LOSS:	4.805
# TRAINING BATCH:	(  130 /   512)	LOSS:	4.799
# TRAINING BATCH:	(  140 /   512)	LOSS:	4.719
# TRAINING BATCH:	(  150 /   512)	LOSS:	4.798
# TRAINING BATCH:	(  160 /   512)	LOSS:	4.775
# TRAINING BATCH:	(  170 /   512)	LOSS:	4.735
# TRAINING BATCH:	(  180 /   512)	LOSS:	4.751
# TRAINING BATCH:	(  190 /   512)	LOSS:	4.773
# TRAINING BATCH:	(  200 /   512)	LOSS:	4.741
# TRAINING BATCH:	(  210 /   512)	LOSS:	4.754
# TRAINING BATCH:	(  220 /   512)	LOSS:	4.792
# TRAINING BATCH:	(  230 /   512)	LOSS:	4.754
# TRAINING BATCH:	(  240 /   512)	LOSS:	4.808
# TRAINING BATCH:	(  250 /   512)	LOSS:	4.778
# TRAINING BATCH:	(  260 /   512)	LOSS:	4.805
# TRAINING BATCH:	(  270 /   512)	LOSS:	4.776
# TRAINING BATCH:	(  280 /   512)	LOSS:	4.823
# TRAINING BATCH:	(  290 /   512)	LOSS:	4.812
# TRAINING BATCH:	(  300 /   512)	LOSS:	4.782
# TRAINING BATCH:	(  310 /   512)	LOSS:	4.752
# TRAINING BATCH:	(  320 /   512)	LOSS:	4.790
# TRAINING BATCH:	(  330 /   512)	LOSS:	4.785
# TRAINING BATCH:	(  340 /   512)	LOSS:	4.773
# TRAINING BATCH:	(  350 /   512)	LOSS:	4.779
# TRAINING BATCH:	(  360 /   512)	LOSS:	4.782
# TRAINING BATCH:	(  370 /   512)	LOSS:	4.835
# TRAINING BATCH:	(  380 /   512)	LOSS:	4.806
# TRAINING BATCH:	(  390 /   512)	LOSS:	4.774
# TRAINING BATCH:	(  400 /   512)	LOSS:	4.741
# TRAINING BATCH:	(  410 /   512)	LOSS:	4.839
# TRAINING BATCH:	(  420 /   512)	LOSS:	4.779
# TRAINING BATCH:	(  430 /   512)	LOSS:	4.788
# TRAINING BATCH:	(  440 /   512)	LOSS:	4.773
# TRAINING BATCH:	(  450 /   512)	LOSS:	4.730
# TRAINING BATCH:	(  460 /   512)	LOSS:	4.714
# TRAINING BATCH:	(  470 /   512)	LOSS:	4.798
# TRAINING BATCH:	(  480 /   512)	LOSS:	4.825
# TRAINING BATCH:	(  490 /   512)	LOSS:	4.758
# TRAINING BATCH:	(  500 /   512)	LOSS:	4.825
# TRAINING BATCH:	(  510 /   512)	LOSS:	4.805
# VALIDATION BATCH:	(    0 /   128)	LOSS:	4.788
# VALIDATION BATCH:	(   10 /   128)	LOSS:	4.748
# VALIDATION BATCH:	(   20 /   128)	LOSS:	4.810
# VALIDATION BATCH:	(   30 /   128)	LOSS:	4.848
# VALIDATION BATCH:	(   40 /   128)	LOSS:	4.772
# VALIDATION BATCH:	(   50 /   128)	LOSS:	4.767
# VALIDATION BATCH:	(   60 /   128)	LOSS:	4.777
# VALIDATION BATCH:	(   70 /   128)	LOSS:	4.764
# VALIDATION BATCH:	(   80 /   128)	LOSS:	4.789
# VALIDATION BATCH:	(   90 /   128)	LOSS:	4.812
# VALIDATION BATCH:	(  100 /   128)	LOSS:	4.805
# VALIDATION BATCH:	(  110 /   128)	LOSS:	4.756
# VALIDATION BATCH:	(  120 /   128)	LOSS:	4.772
# EPOCH:	    2	TRAIN LOSS:	4.782	TRAIN ACCURACY:	0.010	VAL LOSS:	4.785	VAL ACCURACY:	0.009
# TRAINING BATCH:	(    0 /   512)	LOSS:	4.738
# TRAINING BATCH:	(   10 /   512)	LOSS:	4.812
# TRAINING BATCH:	(   20 /   512)	LOSS:	4.772
# TRAINING BATCH:	(   30 /   512)	LOSS:	4.761
# TRAINING BATCH:	(   40 /   512)	LOSS:	4.796
# TRAINING BATCH:	(   50 /   512)	LOSS:	4.782
# TRAINING BATCH:	(   60 /   512)	LOSS:	4.835
# TRAINING BATCH:	(   70 /   512)	LOSS:	4.814
# TRAINING BATCH:	(   80 /   512)	LOSS:	4.812
# TRAINING BATCH:	(   90 /   512)	LOSS:	4.726
# TRAINING BATCH:	(  100 /   512)	LOSS:	4.770
# TRAINING BATCH:	(  110 /   512)	LOSS:	4.799
# TRAINING BATCH:	(  120 /   512)	LOSS:	4.784
# TRAINING BATCH:	(  130 /   512)	LOSS:	4.783
# TRAINING BATCH:	(  140 /   512)	LOSS:	4.774
# TRAINING BATCH:	(  150 /   512)	LOSS:	4.725
# TRAINING BATCH:	(  160 /   512)	LOSS:	4.792
# TRAINING BATCH:	(  170 /   512)	LOSS:	4.820
# TRAINING BATCH:	(  180 /   512)	LOSS:	4.743
# TRAINING BATCH:	(  190 /   512)	LOSS:	4.809
# TRAINING BATCH:	(  200 /   512)	LOSS:	4.748
# TRAINING BATCH:	(  210 /   512)	LOSS:	4.730
# TRAINING BATCH:	(  220 /   512)	LOSS:	4.779
# TRAINING BATCH:	(  230 /   512)	LOSS:	4.826
# TRAINING BATCH:	(  240 /   512)	LOSS:	4.792
# TRAINING BATCH:	(  250 /   512)	LOSS:	4.812
# TRAINING BATCH:	(  260 /   512)	LOSS:	4.818
# TRAINING BATCH:	(  270 /   512)	LOSS:	4.791
# TRAINING BATCH:	(  280 /   512)	LOSS:	4.755
# TRAINING BATCH:	(  290 /   512)	LOSS:	4.841
# TRAINING BATCH:	(  300 /   512)	LOSS:	4.776
# TRAINING BATCH:	(  310 /   512)	LOSS:	4.769
# TRAINING BATCH:	(  320 /   512)	LOSS:	4.776
# TRAINING BATCH:	(  330 /   512)	LOSS:	4.763
# TRAINING BATCH:	(  340 /   512)	LOSS:	4.820
# TRAINING BATCH:	(  350 /   512)	LOSS:	4.801
# TRAINING BATCH:	(  360 /   512)	LOSS:	4.815
# TRAINING BATCH:	(  370 /   512)	LOSS:	4.807
# TRAINING BATCH:	(  380 /   512)	LOSS:	4.756
# TRAINING BATCH:	(  390 /   512)	LOSS:	4.807
# TRAINING BATCH:	(  400 /   512)	LOSS:	4.804
# TRAINING BATCH:	(  410 /   512)	LOSS:	4.757
# TRAINING BATCH:	(  420 /   512)	LOSS:	4.789
# TRAINING BATCH:	(  430 /   512)	LOSS:	4.774
# TRAINING BATCH:	(  440 /   512)	LOSS:	4.803
# TRAINING BATCH:	(  450 /   512)	LOSS:	4.764
# TRAINING BATCH:	(  460 /   512)	LOSS:	4.809
# TRAINING BATCH:	(  470 /   512)	LOSS:	4.737
# TRAINING BATCH:	(  480 /   512)	LOSS:	4.766
# TRAINING BATCH:	(  490 /   512)	LOSS:	4.782
# TRAINING BATCH:	(  500 /   512)	LOSS:	4.761
# TRAINING BATCH:	(  510 /   512)	LOSS:	4.790
# VALIDATION BATCH:	(    0 /   128)	LOSS:	4.793
# VALIDATION BATCH:	(   10 /   128)	LOSS:	4.739
# VALIDATION BATCH:	(   20 /   128)	LOSS:	4.809
# VALIDATION BATCH:	(   30 /   128)	LOSS:	4.853
# VALIDATION BATCH:	(   40 /   128)	LOSS:	4.773
# VALIDATION BATCH:	(   50 /   128)	LOSS:	4.769
# VALIDATION BATCH:	(   60 /   128)	LOSS:	4.783
# VALIDATION BATCH:	(   70 /   128)	LOSS:	4.766
# VALIDATION BATCH:	(   80 /   128)	LOSS:	4.780
# VALIDATION BATCH:	(   90 /   128)	LOSS:	4.813
# VALIDATION BATCH:	(  100 /   128)	LOSS:	4.809
# VALIDATION BATCH:	(  110 /   128)	LOSS:	4.751
# VALIDATION BATCH:	(  120 /   128)	LOSS:	4.776
# EPOCH:	    3	TRAIN LOSS:	4.780	TRAIN ACCURACY:	0.011	VAL LOSS:	4.786	VAL ACCURACY:	0.009
# TRAINING BATCH:	(    0 /   512)	LOSS:	4.756
# TRAINING BATCH:	(   10 /   512)	LOSS:	4.788
# TRAINING BATCH:	(   20 /   512)	LOSS:	4.771
# TRAINING BATCH:	(   30 /   512)	LOSS:	4.767
# TRAINING BATCH:	(   40 /   512)	LOSS:	4.756
# TRAINING BATCH:	(   50 /   512)	LOSS:	4.767
# TRAINING BATCH:	(   60 /   512)	LOSS:	4.765
# TRAINING BATCH:	(   70 /   512)	LOSS:	4.818
# TRAINING BATCH:	(   80 /   512)	LOSS:	4.777
# TRAINING BATCH:	(   90 /   512)	LOSS:	4.821
# TRAINING BATCH:	(  100 /   512)	LOSS:	4.730
# TRAINING BATCH:	(  110 /   512)	LOSS:	4.825
# TRAINING BATCH:	(  120 /   512)	LOSS:	4.747
# TRAINING BATCH:	(  130 /   512)	LOSS:	4.805
# TRAINING BATCH:	(  140 /   512)	LOSS:	4.743
# TRAINING BATCH:	(  150 /   512)	LOSS:	4.721
# TRAINING BATCH:	(  160 /   512)	LOSS:	4.774
# TRAINING BATCH:	(  170 /   512)	LOSS:	4.843
# TRAINING BATCH:	(  180 /   512)	LOSS:	4.832
# TRAINING BATCH:	(  190 /   512)	LOSS:	4.826
# TRAINING BATCH:	(  200 /   512)	LOSS:	4.680
# TRAINING BATCH:	(  210 /   512)	LOSS:	4.837
# TRAINING BATCH:	(  220 /   512)	LOSS:	4.772
# TRAINING BATCH:	(  230 /   512)	LOSS:	4.814
# TRAINING BATCH:	(  240 /   512)	LOSS:	4.771
# TRAINING BATCH:	(  250 /   512)	LOSS:	4.838
# TRAINING BATCH:	(  260 /   512)	LOSS:	4.738
# TRAINING BATCH:	(  270 /   512)	LOSS:	4.719
# TRAINING BATCH:	(  280 /   512)	LOSS:	4.802
# TRAINING BATCH:	(  290 /   512)	LOSS:	4.736
# TRAINING BATCH:	(  300 /   512)	LOSS:	4.790
# TRAINING BATCH:	(  310 /   512)	LOSS:	4.793
# TRAINING BATCH:	(  320 /   512)	LOSS:	4.789
# TRAINING BATCH:	(  330 /   512)	LOSS:	4.825
# TRAINING BATCH:	(  340 /   512)	LOSS:	4.768
# TRAINING BATCH:	(  350 /   512)	LOSS:	4.803
# TRAINING BATCH:	(  360 /   512)	LOSS:	4.746
# TRAINING BATCH:	(  370 /   512)	LOSS:	4.818
# TRAINING BATCH:	(  380 /   512)	LOSS:	4.741
# TRAINING BATCH:	(  390 /   512)	LOSS:	4.815
# TRAINING BATCH:	(  400 /   512)	LOSS:	4.795
# TRAINING BATCH:	(  410 /   512)	LOSS:	4.819
# TRAINING BATCH:	(  420 /   512)	LOSS:	4.732
# TRAINING BATCH:	(  430 /   512)	LOSS:	4.739
# TRAINING BATCH:	(  440 /   512)	LOSS:	4.811
# TRAINING BATCH:	(  450 /   512)	LOSS:	4.809
# TRAINING BATCH:	(  460 /   512)	LOSS:	4.774
# TRAINING BATCH:	(  470 /   512)	LOSS:	4.776
# TRAINING BATCH:	(  480 /   512)	LOSS:	4.797
# TRAINING BATCH:	(  490 /   512)	LOSS:	4.792
# TRAINING BATCH:	(  500 /   512)	LOSS:	4.767
# TRAINING BATCH:	(  510 /   512)	LOSS:	4.740
# VALIDATION BATCH:	(    0 /   128)	LOSS:	4.793
# VALIDATION BATCH:	(   10 /   128)	LOSS:	4.733
# VALIDATION BATCH:	(   20 /   128)	LOSS:	4.810
# VALIDATION BATCH:	(   30 /   128)	LOSS:	4.866
# VALIDATION BATCH:	(   40 /   128)	LOSS:	4.777
# VALIDATION BATCH:	(   50 /   128)	LOSS:	4.760
# VALIDATION BATCH:	(   60 /   128)	LOSS:	4.774
# VALIDATION BATCH:	(   70 /   128)	LOSS:	4.767
# VALIDATION BATCH:	(   80 /   128)	LOSS:	4.788
# VALIDATION BATCH:	(   90 /   128)	LOSS:	4.819
# VALIDATION BATCH:	(  100 /   128)	LOSS:	4.811
# VALIDATION BATCH:	(  110 /   128)	LOSS:	4.755
# VALIDATION BATCH:	(  120 /   128)	LOSS:	4.767
# EPOCH:	    4	TRAIN LOSS:	4.779	TRAIN ACCURACY:	0.012	VAL LOSS:	4.786	VAL ACCURACY:	0.015
# TRAINING BATCH:	(    0 /   512)	LOSS:	4.749
# TRAINING BATCH:	(   10 /   512)	LOSS:	4.813
# TRAINING BATCH:	(   20 /   512)	LOSS:	4.807
# TRAINING BATCH:	(   30 /   512)	LOSS:	4.766
# TRAINING BATCH:	(   40 /   512)	LOSS:	4.794
# TRAINING BATCH:	(   50 /   512)	LOSS:	4.760
# TRAINING BATCH:	(   60 /   512)	LOSS:	4.811
# TRAINING BATCH:	(   70 /   512)	LOSS:	4.793
# TRAINING BATCH:	(   80 /   512)	LOSS:	4.712
# TRAINING BATCH:	(   90 /   512)	LOSS:	4.813
# TRAINING BATCH:	(  100 /   512)	LOSS:	4.750
# TRAINING BATCH:	(  110 /   512)	LOSS:	4.767
# TRAINING BATCH:	(  120 /   512)	LOSS:	4.852
# TRAINING BATCH:	(  130 /   512)	LOSS:	4.789
# TRAINING BATCH:	(  140 /   512)	LOSS:	4.825
# TRAINING BATCH:	(  150 /   512)	LOSS:	4.739
# TRAINING BATCH:	(  160 /   512)	LOSS:	4.805
# TRAINING BATCH:	(  170 /   512)	LOSS:	4.795
# TRAINING BATCH:	(  180 /   512)	LOSS:	4.773
# TRAINING BATCH:	(  190 /   512)	LOSS:	4.759
# TRAINING BATCH:	(  200 /   512)	LOSS:	4.762
# TRAINING BATCH:	(  210 /   512)	LOSS:	4.810
# TRAINING BATCH:	(  220 /   512)	LOSS:	4.761
# TRAINING BATCH:	(  230 /   512)	LOSS:	4.746
# TRAINING BATCH:	(  240 /   512)	LOSS:	4.775
# TRAINING BATCH:	(  250 /   512)	LOSS:	4.804
# TRAINING BATCH:	(  260 /   512)	LOSS:	4.736
# TRAINING BATCH:	(  270 /   512)	LOSS:	4.787
# TRAINING BATCH:	(  280 /   512)	LOSS:	4.781
# TRAINING BATCH:	(  290 /   512)	LOSS:	4.835
# TRAINING BATCH:	(  300 /   512)	LOSS:	4.757
# TRAINING BATCH:	(  310 /   512)	LOSS:	4.802
# TRAINING BATCH:	(  320 /   512)	LOSS:	4.797
# TRAINING BATCH:	(  330 /   512)	LOSS:	4.814
# TRAINING BATCH:	(  340 /   512)	LOSS:	4.813
# TRAINING BATCH:	(  350 /   512)	LOSS:	4.723
# TRAINING BATCH:	(  360 /   512)	LOSS:	4.767
# TRAINING BATCH:	(  370 /   512)	LOSS:	4.799
# TRAINING BATCH:	(  380 /   512)	LOSS:	4.738
# TRAINING BATCH:	(  390 /   512)	LOSS:	4.786
# TRAINING BATCH:	(  400 /   512)	LOSS:	4.786
# TRAINING BATCH:	(  410 /   512)	LOSS:	4.807
# TRAINING BATCH:	(  420 /   512)	LOSS:	4.767
# TRAINING BATCH:	(  430 /   512)	LOSS:	4.795
# TRAINING BATCH:	(  440 /   512)	LOSS:	4.777
# TRAINING BATCH:	(  450 /   512)	LOSS:	4.862
# TRAINING BATCH:	(  460 /   512)	LOSS:	4.754
# TRAINING BATCH:	(  470 /   512)	LOSS:	4.724
# TRAINING BATCH:	(  480 /   512)	LOSS:	4.790
# TRAINING BATCH:	(  490 /   512)	LOSS:	4.842
# TRAINING BATCH:	(  500 /   512)	LOSS:	4.829
# TRAINING BATCH:	(  510 /   512)	LOSS:	4.723
# VALIDATION BATCH:	(    0 /   128)	LOSS:	4.804
# VALIDATION BATCH:	(   10 /   128)	LOSS:	4.730
# VALIDATION BATCH:	(   20 /   128)	LOSS:	4.813
# VALIDATION BATCH:	(   30 /   128)	LOSS:	4.868
# VALIDATION BATCH:	(   40 /   128)	LOSS:	4.773
# VALIDATION BATCH:	(   50 /   128)	LOSS:	4.764
# VALIDATION BATCH:	(   60 /   128)	LOSS:	4.786
# VALIDATION BATCH:	(   70 /   128)	LOSS:	4.764
# VALIDATION BATCH:	(   80 /   128)	LOSS:	4.781
# VALIDATION BATCH:	(   90 /   128)	LOSS:	4.825
# VALIDATION BATCH:	(  100 /   128)	LOSS:	4.813
# VALIDATION BATCH:	(  110 /   128)	LOSS:	4.745
# VALIDATION BATCH:	(  120 /   128)	LOSS:	4.775
# EPOCH:	    5	TRAIN LOSS:	4.779	TRAIN ACCURACY:	0.012	VAL LOSS:	4.786	VAL ACCURACY:	0.009

# %% [markdown]
# We recycle the plotting function of lab 6 to plot the training progress:

# %%
def get_training_progress_plot(
        train_losses: list[float],
        train_accs: list[float],
        val_losses: list[float],
        val_accs: list[float],
) -> None:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(7, 2))

    ax1.set_title('Loss')
    ax1.plot(train_losses, label='Train Loss')
    ax1.plot(val_losses, label='Val Loss')
    ax1.legend()

    ax2.set_title('Accuracy')
    ax2.plot(train_accs, label='Train Accuracy')
    ax2.plot(val_accs, label='Val Accuracy')
    ax2.legend()

get_training_progress_plot(
    metrics['train_loss'],
    metrics['train_acc'],
    metrics['val_loss'],
    metrics['val_acc'],
)

# %% [markdown]
# ## Using a pretrained network
# Even with the aid of data augmentation, the network does not perform good. This can be
# explained by the fact that the images are quite diverse in relation to the size of the
# training set. Data augmentation can only bring you so far, and even with the aid of
# regularization the task would be difficult.
#
# One popular trick to overcome this difficulty, known as _pre-training_, is to use another
# CNN that has been trained on a different, larger dataset, for a related task. Most of the
# weights of this network are then frozen (i.e., will not be updated),
# and the last few layers (the "head") are replaced with new, freshly re-initialized ones
# and learned from scratch.
# What is the rationale behind freezing and unfreezing the weights?
#
# PyTorch offers a variety of [pretrained models to download](https://pytorch.org/vision/stable/models.html).
#
# After obtaining VGG16, our plan is to:
#
#     1. Get the body of the downloaded net (accessible over `features` attribute)
#     2. Create an extra head.
#     3. Train only the weights of the head.

# %%
vgg_body = vgg16(pretrained=True, progress=False).features.to(device)
vgg_head = nn.Sequential(
    nn.AdaptiveAvgPool2d((1, 1)),
    nn.Flatten(),
    nn.Linear(in_features=512, out_features=512),
    nn.ReLU(),
    nn.Linear(in_features=512, out_features=512),
    nn.ReLU(),
    nn.Linear(in_features=512, out_features=120),
).to(device)

head_optimizer = (
    Adam(vgg_head.parameters())
)
# Out:
# /home/emanuel/Documents/teaching/SS24/lecture_i2dl/exercises/python/.venv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/emanuel/Documents/teaching/SS24/lecture_i2dl/exercises/python/.venv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# The documentation of VGG16 reveals that input images should be normalized with a given
# range. Thus, we need to adjust the transforms of our datasets:

# %%
normalize_transform = transforms.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225]
)

# Note: The clean way would be creating new datasets instead of modifiying internal structures.
train_dataset.transform.transforms.append(normalize_transform)
val_dataset.transform.transforms.append(normalize_transform)

# %% [markdown]
# In the next step, we modify our train function to implement the desired behaviour.
# We train only the head for 10 epochs and then allow optimization of everything.

# %%
epochs = 15

def train(
        head: nn.Module,
        body: nn.Module,
        loss: nn.Module,
        head_optimizer: Optimizer,
        train_loader: DataLoader,
        val_loader: DataLoader,
        epochs: int
) -> dict:
    # Intermediate results during training will be saved here.
    # This allows plotting the training progress afterwards.
    metrics: dict = {
        'train_loss': [],
        'train_acc': [],
        'val_loss': [],
        'val_acc': [],
    }

    num_train_batches = ceil(len(train_loader.dataset) / batch_size)
    num_val_batches = ceil(len(val_loader.dataset) / batch_size)

    for ep in range(1, epochs + 1):
        total_loss = 0
        num_correct = 0

        for batch_idx, (x, y) in enumerate(train_loader):
            x = x.to(device)
            y = y.to(device)

            with torch.no_grad():
                x_features = body(x)
            y_hat = head(x_features)
            batch_loss = loss(y_hat, y)
            
            head_optimizer.zero_grad()
            batch_loss.backward()
            head_optimizer.step()

            if batch_idx % 10 == 0:
                print('TRAINING BATCH:\t({:5} / {:5})\tLOSS:\t{:.3f}'
                      .format(batch_idx, num_train_batches, float(batch_loss)), end='\r')

            total_loss += float(batch_loss)
            num_correct += int(torch.sum(torch.argmax(y_hat, dim=1) == y))


        ep_train_loss = total_loss / num_train_batches
        ep_train_acc = num_correct / len(train_loader.dataset)

        # Reset counters
        total_loss = 0
        num_correct = 0

        for batch_idx, (x, y) in enumerate(val_loader):
            x = x.to(device)
            y = y.to(device)

            with torch.no_grad():
                y_hat = head(body(x))
                batch_loss = loss(y_hat, y)

            if batch_idx % 10 == 0:
                print('VALIDATION BATCH:\t({:5} / {:5})\tLOSS:\t{:.3f}'
                      .format(batch_idx, num_val_batches, float(batch_loss)), end='\r')

            total_loss += float(batch_loss)
            num_correct += int(torch.sum(torch.argmax(y_hat, dim=1) == y))

        ep_val_loss = total_loss / num_val_batches
        ep_val_acc = num_correct / len(val_loader.dataset)

        metrics['train_loss'].append(ep_train_loss)
        metrics['train_acc'].append(ep_train_acc)
        metrics['val_loss'].append(ep_val_loss)
        metrics['val_acc'].append(ep_val_acc)

        print('EPOCH:\t{:5}\tTRAIN LOSS:\t{:.3f}\tTRAIN ACCURACY:\t{:.3f}\tVAL LOSS:\t'
              '{:.3f}\tVAL ACCURACY:\t{:.3f}'
              .format(ep, ep_train_loss, ep_train_acc,ep_val_loss, ep_val_acc,
                      end='\r'))
    return metrics

metrics = train(
    head=vgg_head,
    body=vgg_body,
    head_optimizer=head_optimizer,
    loss=loss,
    train_loader=train_loader,
    val_loader=val_loader,
    epochs=epochs
)
# Out:
# TRAINING BATCH:	(    0 /   512)	LOSS:	4.803
# TRAINING BATCH:	(   10 /   512)	LOSS:	4.714
# TRAINING BATCH:	(   20 /   512)	LOSS:	4.885
# TRAINING BATCH:	(   30 /   512)	LOSS:	4.737
# TRAINING BATCH:	(   40 /   512)	LOSS:	4.751
# TRAINING BATCH:	(   50 /   512)	LOSS:	4.586
# TRAINING BATCH:	(   60 /   512)	LOSS:	4.209
# TRAINING BATCH:	(   70 /   512)	LOSS:	4.342
# TRAINING BATCH:	(   80 /   512)	LOSS:	4.290
# TRAINING BATCH:	(   90 /   512)	LOSS:	4.104
# TRAINING BATCH:	(  100 /   512)	LOSS:	3.841
# TRAINING BATCH:	(  110 /   512)	LOSS:	3.082
# TRAINING BATCH:	(  120 /   512)	LOSS:	3.011
# TRAINING BATCH:	(  130 /   512)	LOSS:	3.232
# TRAINING BATCH:	(  140 /   512)	LOSS:	3.387
# TRAINING BATCH:	(  150 /   512)	LOSS:	2.962
# TRAINING BATCH:	(  160 /   512)	LOSS:	2.487
# TRAINING BATCH:	(  170 /   512)	LOSS:	3.349
# TRAINING BATCH:	(  180 /   512)	LOSS:	3.141
# TRAINING BATCH:	(  190 /   512)	LOSS:	2.720
# TRAINING BATCH:	(  200 /   512)	LOSS:	2.822
# TRAINING BATCH:	(  210 /   512)	LOSS:	2.877
# TRAINING BATCH:	(  220 /   512)	LOSS:	2.693
# TRAINING BATCH:	(  230 /   512)	LOSS:	3.286
# TRAINING BATCH:	(  240 /   512)	LOSS:	2.654
# TRAINING BATCH:	(  250 /   512)	LOSS:	2.538
# TRAINING BATCH:	(  260 /   512)	LOSS:	2.361
# TRAINING BATCH:	(  270 /   512)	LOSS:	2.821
# TRAINING BATCH:	(  280 /   512)	LOSS:	2.147
# TRAINING BATCH:	(  290 /   512)	LOSS:	2.735
# TRAINING BATCH:	(  300 /   512)	LOSS:	2.942
# TRAINING BATCH:	(  310 /   512)	LOSS:	3.616
# TRAINING BATCH:	(  320 /   512)	LOSS:	2.219
# TRAINING BATCH:	(  330 /   512)	LOSS:	2.294
# TRAINING BATCH:	(  340 /   512)	LOSS:	2.300
# TRAINING BATCH:	(  350 /   512)	LOSS:	2.086
# TRAINING BATCH:	(  360 /   512)	LOSS:	2.009
# TRAINING BATCH:	(  370 /   512)	LOSS:	2.059
# TRAINING BATCH:	(  380 /   512)	LOSS:	2.153
# TRAINING BATCH:	(  390 /   512)	LOSS:	2.195
# TRAINING BATCH:	(  400 /   512)	LOSS:	2.263
# TRAINING BATCH:	(  410 /   512)	LOSS:	2.528
# TRAINING BATCH:	(  420 /   512)	LOSS:	2.696
# TRAINING BATCH:	(  430 /   512)	LOSS:	2.690
# TRAINING BATCH:	(  440 /   512)	LOSS:	2.474
# TRAINING BATCH:	(  450 /   512)	LOSS:	2.295
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.917
# TRAINING BATCH:	(  470 /   512)	LOSS:	2.299
# TRAINING BATCH:	(  480 /   512)	LOSS:	2.484
# TRAINING BATCH:	(  490 /   512)	LOSS:	2.640
# TRAINING BATCH:	(  500 /   512)	LOSS:	2.268
# TRAINING BATCH:	(  510 /   512)	LOSS:	2.364
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.811
# VALIDATION BATCH:	(   10 /   128)	LOSS:	1.569
# VALIDATION BATCH:	(   20 /   128)	LOSS:	1.741
# VALIDATION BATCH:	(   30 /   128)	LOSS:	2.137
# VALIDATION BATCH:	(   40 /   128)	LOSS:	1.122
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.930
# VALIDATION BATCH:	(   60 /   128)	LOSS:	1.545
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.390
# VALIDATION BATCH:	(   80 /   128)	LOSS:	1.033
# VALIDATION BATCH:	(   90 /   128)	LOSS:	1.623
# VALIDATION BATCH:	(  100 /   128)	LOSS:	1.379
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.980
# VALIDATION BATCH:	(  120 /   128)	LOSS:	1.284
# EPOCH:	    1	TRAIN LOSS:	3.022	TRAIN ACCURACY:	0.248	VAL LOSS:	1.496	VAL ACCURACY:	0.549
# TRAINING BATCH:	(    0 /   512)	LOSS:	2.082
# TRAINING BATCH:	(   10 /   512)	LOSS:	2.159
# TRAINING BATCH:	(   20 /   512)	LOSS:	2.042
# TRAINING BATCH:	(   30 /   512)	LOSS:	2.467
# TRAINING BATCH:	(   40 /   512)	LOSS:	2.213
# TRAINING BATCH:	(   50 /   512)	LOSS:	1.837
# TRAINING BATCH:	(   60 /   512)	LOSS:	2.891
# TRAINING BATCH:	(   70 /   512)	LOSS:	2.092
# TRAINING BATCH:	(   80 /   512)	LOSS:	1.687
# TRAINING BATCH:	(   90 /   512)	LOSS:	1.789
# TRAINING BATCH:	(  100 /   512)	LOSS:	1.682
# TRAINING BATCH:	(  110 /   512)	LOSS:	2.724
# TRAINING BATCH:	(  120 /   512)	LOSS:	2.167
# TRAINING BATCH:	(  130 /   512)	LOSS:	2.323
# TRAINING BATCH:	(  140 /   512)	LOSS:	2.027
# TRAINING BATCH:	(  150 /   512)	LOSS:	2.296
# TRAINING BATCH:	(  160 /   512)	LOSS:	2.651
# TRAINING BATCH:	(  170 /   512)	LOSS:	2.702
# TRAINING BATCH:	(  180 /   512)	LOSS:	2.548
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.621
# TRAINING BATCH:	(  200 /   512)	LOSS:	1.978
# TRAINING BATCH:	(  210 /   512)	LOSS:	1.943
# TRAINING BATCH:	(  220 /   512)	LOSS:	1.740
# TRAINING BATCH:	(  230 /   512)	LOSS:	1.241
# TRAINING BATCH:	(  240 /   512)	LOSS:	2.269
# TRAINING BATCH:	(  250 /   512)	LOSS:	2.194
# TRAINING BATCH:	(  260 /   512)	LOSS:	2.344
# TRAINING BATCH:	(  270 /   512)	LOSS:	2.379
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.960
# TRAINING BATCH:	(  290 /   512)	LOSS:	2.625
# TRAINING BATCH:	(  300 /   512)	LOSS:	1.767
# TRAINING BATCH:	(  310 /   512)	LOSS:	1.972
# TRAINING BATCH:	(  320 /   512)	LOSS:	1.960
# TRAINING BATCH:	(  330 /   512)	LOSS:	2.477
# TRAINING BATCH:	(  340 /   512)	LOSS:	2.605
# TRAINING BATCH:	(  350 /   512)	LOSS:	1.856
# TRAINING BATCH:	(  360 /   512)	LOSS:	1.126
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.436
# TRAINING BATCH:	(  380 /   512)	LOSS:	1.948
# TRAINING BATCH:	(  390 /   512)	LOSS:	2.079
# TRAINING BATCH:	(  400 /   512)	LOSS:	1.917
# TRAINING BATCH:	(  410 /   512)	LOSS:	2.494
# TRAINING BATCH:	(  420 /   512)	LOSS:	2.423
# TRAINING BATCH:	(  430 /   512)	LOSS:	2.176
# TRAINING BATCH:	(  440 /   512)	LOSS:	2.161
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.579
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.849
# TRAINING BATCH:	(  470 /   512)	LOSS:	2.296
# TRAINING BATCH:	(  480 /   512)	LOSS:	1.517
# TRAINING BATCH:	(  490 /   512)	LOSS:	1.390
# TRAINING BATCH:	(  500 /   512)	LOSS:	2.804
# TRAINING BATCH:	(  510 /   512)	LOSS:	2.799
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.249
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.725
# VALIDATION BATCH:	(   20 /   128)	LOSS:	1.684
# VALIDATION BATCH:	(   30 /   128)	LOSS:	1.626
# VALIDATION BATCH:	(   40 /   128)	LOSS:	0.849
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.865
# VALIDATION BATCH:	(   60 /   128)	LOSS:	1.185
# VALIDATION BATCH:	(   70 /   128)	LOSS:	0.727
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.410
# VALIDATION BATCH:	(   90 /   128)	LOSS:	1.318
# VALIDATION BATCH:	(  100 /   128)	LOSS:	1.172
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.612
# VALIDATION BATCH:	(  120 /   128)	LOSS:	1.010
# EPOCH:	    2	TRAIN LOSS:	2.044	TRAIN ACCURACY:	0.424	VAL LOSS:	1.208	VAL ACCURACY:	0.613
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.549
# TRAINING BATCH:	(   10 /   512)	LOSS:	2.494
# TRAINING BATCH:	(   20 /   512)	LOSS:	2.001
# TRAINING BATCH:	(   30 /   512)	LOSS:	1.144
# TRAINING BATCH:	(   40 /   512)	LOSS:	2.285
# TRAINING BATCH:	(   50 /   512)	LOSS:	1.992
# TRAINING BATCH:	(   60 /   512)	LOSS:	2.123
# TRAINING BATCH:	(   70 /   512)	LOSS:	1.529
# TRAINING BATCH:	(   80 /   512)	LOSS:	2.602
# TRAINING BATCH:	(   90 /   512)	LOSS:	2.230
# TRAINING BATCH:	(  100 /   512)	LOSS:	1.656
# TRAINING BATCH:	(  110 /   512)	LOSS:	1.665
# TRAINING BATCH:	(  120 /   512)	LOSS:	1.358
# TRAINING BATCH:	(  130 /   512)	LOSS:	1.406
# TRAINING BATCH:	(  140 /   512)	LOSS:	1.812
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.228
# TRAINING BATCH:	(  160 /   512)	LOSS:	1.871
# TRAINING BATCH:	(  170 /   512)	LOSS:	2.191
# TRAINING BATCH:	(  180 /   512)	LOSS:	2.522
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.912
# TRAINING BATCH:	(  200 /   512)	LOSS:	1.592
# TRAINING BATCH:	(  210 /   512)	LOSS:	2.191
# TRAINING BATCH:	(  220 /   512)	LOSS:	1.896
# TRAINING BATCH:	(  230 /   512)	LOSS:	2.033
# TRAINING BATCH:	(  240 /   512)	LOSS:	1.426
# TRAINING BATCH:	(  250 /   512)	LOSS:	1.557
# TRAINING BATCH:	(  260 /   512)	LOSS:	1.563
# TRAINING BATCH:	(  270 /   512)	LOSS:	1.949
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.682
# TRAINING BATCH:	(  290 /   512)	LOSS:	2.075
# TRAINING BATCH:	(  300 /   512)	LOSS:	1.735
# TRAINING BATCH:	(  310 /   512)	LOSS:	2.420
# TRAINING BATCH:	(  320 /   512)	LOSS:	2.286
# TRAINING BATCH:	(  330 /   512)	LOSS:	1.880
# TRAINING BATCH:	(  340 /   512)	LOSS:	1.968
# TRAINING BATCH:	(  350 /   512)	LOSS:	1.634
# TRAINING BATCH:	(  360 /   512)	LOSS:	1.960
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.776
# TRAINING BATCH:	(  380 /   512)	LOSS:	2.219
# TRAINING BATCH:	(  390 /   512)	LOSS:	1.759
# TRAINING BATCH:	(  400 /   512)	LOSS:	1.832
# TRAINING BATCH:	(  410 /   512)	LOSS:	2.270
# TRAINING BATCH:	(  420 /   512)	LOSS:	2.005
# TRAINING BATCH:	(  430 /   512)	LOSS:	0.969
# TRAINING BATCH:	(  440 /   512)	LOSS:	1.720
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.333
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.580
# TRAINING BATCH:	(  470 /   512)	LOSS:	1.223
# TRAINING BATCH:	(  480 /   512)	LOSS:	1.851
# TRAINING BATCH:	(  490 /   512)	LOSS:	1.969
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.454
# TRAINING BATCH:	(  510 /   512)	LOSS:	2.901
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.418
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.884
# VALIDATION BATCH:	(   20 /   128)	LOSS:	2.125
# VALIDATION BATCH:	(   30 /   128)	LOSS:	1.278
# VALIDATION BATCH:	(   40 /   128)	LOSS:	1.113
# VALIDATION BATCH:	(   50 /   128)	LOSS:	1.040
# VALIDATION BATCH:	(   60 /   128)	LOSS:	1.365
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.399
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.570
# VALIDATION BATCH:	(   90 /   128)	LOSS:	0.900
# VALIDATION BATCH:	(  100 /   128)	LOSS:	1.361
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.410
# VALIDATION BATCH:	(  120 /   128)	LOSS:	1.142
# EPOCH:	    3	TRAIN LOSS:	1.875	TRAIN ACCURACY:	0.479	VAL LOSS:	1.204	VAL ACCURACY:	0.644
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.326
# TRAINING BATCH:	(   10 /   512)	LOSS:	1.727
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.995
# TRAINING BATCH:	(   30 /   512)	LOSS:	2.496
# TRAINING BATCH:	(   40 /   512)	LOSS:	1.413
# TRAINING BATCH:	(   50 /   512)	LOSS:	0.991
# TRAINING BATCH:	(   60 /   512)	LOSS:	1.782
# TRAINING BATCH:	(   70 /   512)	LOSS:	2.143
# TRAINING BATCH:	(   80 /   512)	LOSS:	1.833
# TRAINING BATCH:	(   90 /   512)	LOSS:	2.146
# TRAINING BATCH:	(  100 /   512)	LOSS:	1.508
# TRAINING BATCH:	(  110 /   512)	LOSS:	2.345
# TRAINING BATCH:	(  120 /   512)	LOSS:	1.893
# TRAINING BATCH:	(  130 /   512)	LOSS:	1.684
# TRAINING BATCH:	(  140 /   512)	LOSS:	1.069
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.758
# TRAINING BATCH:	(  160 /   512)	LOSS:	2.108
# TRAINING BATCH:	(  170 /   512)	LOSS:	1.494
# TRAINING BATCH:	(  180 /   512)	LOSS:	1.579
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.920
# TRAINING BATCH:	(  200 /   512)	LOSS:	1.139
# TRAINING BATCH:	(  210 /   512)	LOSS:	1.983
# TRAINING BATCH:	(  220 /   512)	LOSS:	2.161
# TRAINING BATCH:	(  230 /   512)	LOSS:	2.189
# TRAINING BATCH:	(  240 /   512)	LOSS:	1.528
# TRAINING BATCH:	(  250 /   512)	LOSS:	2.111
# TRAINING BATCH:	(  260 /   512)	LOSS:	1.806
# TRAINING BATCH:	(  270 /   512)	LOSS:	2.314
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.918
# TRAINING BATCH:	(  290 /   512)	LOSS:	1.180
# TRAINING BATCH:	(  300 /   512)	LOSS:	1.495
# TRAINING BATCH:	(  310 /   512)	LOSS:	1.659
# TRAINING BATCH:	(  320 /   512)	LOSS:	1.582
# TRAINING BATCH:	(  330 /   512)	LOSS:	1.800
# TRAINING BATCH:	(  340 /   512)	LOSS:	1.267
# TRAINING BATCH:	(  350 /   512)	LOSS:	1.800
# TRAINING BATCH:	(  360 /   512)	LOSS:	1.835
# TRAINING BATCH:	(  370 /   512)	LOSS:	2.034
# TRAINING BATCH:	(  380 /   512)	LOSS:	1.436
# TRAINING BATCH:	(  390 /   512)	LOSS:	1.079
# TRAINING BATCH:	(  400 /   512)	LOSS:	2.149
# TRAINING BATCH:	(  410 /   512)	LOSS:	1.192
# TRAINING BATCH:	(  420 /   512)	LOSS:	1.588
# TRAINING BATCH:	(  430 /   512)	LOSS:	2.122
# TRAINING BATCH:	(  440 /   512)	LOSS:	1.193
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.781
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.363
# TRAINING BATCH:	(  470 /   512)	LOSS:	1.820
# TRAINING BATCH:	(  480 /   512)	LOSS:	1.376
# TRAINING BATCH:	(  490 /   512)	LOSS:	1.347
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.771
# TRAINING BATCH:	(  510 /   512)	LOSS:	2.560
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.385
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.773
# VALIDATION BATCH:	(   20 /   128)	LOSS:	1.694
# VALIDATION BATCH:	(   30 /   128)	LOSS:	1.798
# VALIDATION BATCH:	(   40 /   128)	LOSS:	0.983
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.737
# VALIDATION BATCH:	(   60 /   128)	LOSS:	0.888
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.187
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.646
# VALIDATION BATCH:	(   90 /   128)	LOSS:	1.123
# VALIDATION BATCH:	(  100 /   128)	LOSS:	1.653
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.649
# VALIDATION BATCH:	(  120 /   128)	LOSS:	1.159
# EPOCH:	    4	TRAIN LOSS:	1.739	TRAIN ACCURACY:	0.507	VAL LOSS:	1.194	VAL ACCURACY:	0.635
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.393
# TRAINING BATCH:	(   10 /   512)	LOSS:	1.690
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.558
# TRAINING BATCH:	(   30 /   512)	LOSS:	1.525
# TRAINING BATCH:	(   40 /   512)	LOSS:	2.043
# TRAINING BATCH:	(   50 /   512)	LOSS:	1.996
# TRAINING BATCH:	(   60 /   512)	LOSS:	1.349
# TRAINING BATCH:	(   70 /   512)	LOSS:	1.659
# TRAINING BATCH:	(   80 /   512)	LOSS:	1.007
# TRAINING BATCH:	(   90 /   512)	LOSS:	1.210
# TRAINING BATCH:	(  100 /   512)	LOSS:	1.672
# TRAINING BATCH:	(  110 /   512)	LOSS:	2.084
# TRAINING BATCH:	(  120 /   512)	LOSS:	0.888
# TRAINING BATCH:	(  130 /   512)	LOSS:	1.109
# TRAINING BATCH:	(  140 /   512)	LOSS:	1.811
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.165
# TRAINING BATCH:	(  160 /   512)	LOSS:	1.215
# TRAINING BATCH:	(  170 /   512)	LOSS:	2.442
# TRAINING BATCH:	(  180 /   512)	LOSS:	2.684
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.397
# TRAINING BATCH:	(  200 /   512)	LOSS:	2.032
# TRAINING BATCH:	(  210 /   512)	LOSS:	1.636
# TRAINING BATCH:	(  220 /   512)	LOSS:	1.391
# TRAINING BATCH:	(  230 /   512)	LOSS:	1.188
# TRAINING BATCH:	(  240 /   512)	LOSS:	1.418
# TRAINING BATCH:	(  250 /   512)	LOSS:	1.504
# TRAINING BATCH:	(  260 /   512)	LOSS:	1.374
# TRAINING BATCH:	(  270 /   512)	LOSS:	1.443
# TRAINING BATCH:	(  280 /   512)	LOSS:	2.268
# TRAINING BATCH:	(  290 /   512)	LOSS:	1.826
# TRAINING BATCH:	(  300 /   512)	LOSS:	2.311
# TRAINING BATCH:	(  310 /   512)	LOSS:	0.896
# TRAINING BATCH:	(  320 /   512)	LOSS:	1.562
# TRAINING BATCH:	(  330 /   512)	LOSS:	1.434
# TRAINING BATCH:	(  340 /   512)	LOSS:	1.902
# TRAINING BATCH:	(  350 /   512)	LOSS:	2.853
# TRAINING BATCH:	(  360 /   512)	LOSS:	1.544
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.115
# TRAINING BATCH:	(  380 /   512)	LOSS:	0.808
# TRAINING BATCH:	(  390 /   512)	LOSS:	1.509
# TRAINING BATCH:	(  400 /   512)	LOSS:	1.552
# TRAINING BATCH:	(  410 /   512)	LOSS:	1.704
# TRAINING BATCH:	(  420 /   512)	LOSS:	1.753
# TRAINING BATCH:	(  430 /   512)	LOSS:	1.777
# TRAINING BATCH:	(  440 /   512)	LOSS:	1.713
# TRAINING BATCH:	(  450 /   512)	LOSS:	2.281
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.697
# TRAINING BATCH:	(  470 /   512)	LOSS:	1.572
# TRAINING BATCH:	(  480 /   512)	LOSS:	2.375
# TRAINING BATCH:	(  490 /   512)	LOSS:	0.945
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.559
# TRAINING BATCH:	(  510 /   512)	LOSS:	1.154
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.166
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.404
# VALIDATION BATCH:	(   20 /   128)	LOSS:	1.542
# VALIDATION BATCH:	(   30 /   128)	LOSS:	0.943
# VALIDATION BATCH:	(   40 /   128)	LOSS:	0.774
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.576
# VALIDATION BATCH:	(   60 /   128)	LOSS:	0.929
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.337
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.651
# VALIDATION BATCH:	(   90 /   128)	LOSS:	0.945
# VALIDATION BATCH:	(  100 /   128)	LOSS:	1.146
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.381
# VALIDATION BATCH:	(  120 /   128)	LOSS:	0.916
# EPOCH:	    5	TRAIN LOSS:	1.642	TRAIN ACCURACY:	0.529	VAL LOSS:	1.087	VAL ACCURACY:	0.680
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.395
# TRAINING BATCH:	(   10 /   512)	LOSS:	1.385
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.251
# TRAINING BATCH:	(   30 /   512)	LOSS:	1.316
# TRAINING BATCH:	(   40 /   512)	LOSS:	1.743
# TRAINING BATCH:	(   50 /   512)	LOSS:	1.542
# TRAINING BATCH:	(   60 /   512)	LOSS:	1.713
# TRAINING BATCH:	(   70 /   512)	LOSS:	0.870
# TRAINING BATCH:	(   80 /   512)	LOSS:	1.845
# TRAINING BATCH:	(   90 /   512)	LOSS:	2.597
# TRAINING BATCH:	(  100 /   512)	LOSS:	2.105
# TRAINING BATCH:	(  110 /   512)	LOSS:	0.832
# TRAINING BATCH:	(  120 /   512)	LOSS:	1.267
# TRAINING BATCH:	(  130 /   512)	LOSS:	2.228
# TRAINING BATCH:	(  140 /   512)	LOSS:	1.261
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.812
# TRAINING BATCH:	(  160 /   512)	LOSS:	1.511
# TRAINING BATCH:	(  170 /   512)	LOSS:	1.717
# TRAINING BATCH:	(  180 /   512)	LOSS:	1.455
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.309
# TRAINING BATCH:	(  200 /   512)	LOSS:	1.838
# TRAINING BATCH:	(  210 /   512)	LOSS:	1.476
# TRAINING BATCH:	(  220 /   512)	LOSS:	1.536
# TRAINING BATCH:	(  230 /   512)	LOSS:	1.542
# TRAINING BATCH:	(  240 /   512)	LOSS:	1.835
# TRAINING BATCH:	(  250 /   512)	LOSS:	1.974
# TRAINING BATCH:	(  260 /   512)	LOSS:	2.106
# TRAINING BATCH:	(  270 /   512)	LOSS:	0.779
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.282
# TRAINING BATCH:	(  290 /   512)	LOSS:	1.897
# TRAINING BATCH:	(  300 /   512)	LOSS:	1.529
# TRAINING BATCH:	(  310 /   512)	LOSS:	1.509
# TRAINING BATCH:	(  320 /   512)	LOSS:	0.637
# TRAINING BATCH:	(  330 /   512)	LOSS:	2.414
# TRAINING BATCH:	(  340 /   512)	LOSS:	2.082
# TRAINING BATCH:	(  350 /   512)	LOSS:	1.920
# TRAINING BATCH:	(  360 /   512)	LOSS:	1.592
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.459
# TRAINING BATCH:	(  380 /   512)	LOSS:	1.868
# TRAINING BATCH:	(  390 /   512)	LOSS:	1.851
# TRAINING BATCH:	(  400 /   512)	LOSS:	2.068
# TRAINING BATCH:	(  410 /   512)	LOSS:	1.717
# TRAINING BATCH:	(  420 /   512)	LOSS:	2.199
# TRAINING BATCH:	(  430 /   512)	LOSS:	1.383
# TRAINING BATCH:	(  440 /   512)	LOSS:	2.115
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.370
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.431
# TRAINING BATCH:	(  470 /   512)	LOSS:	1.276
# TRAINING BATCH:	(  480 /   512)	LOSS:	1.524
# TRAINING BATCH:	(  490 /   512)	LOSS:	1.657
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.850
# TRAINING BATCH:	(  510 /   512)	LOSS:	2.096
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.237
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.351
# VALIDATION BATCH:	(   20 /   128)	LOSS:	1.734
# VALIDATION BATCH:	(   30 /   128)	LOSS:	1.126
# VALIDATION BATCH:	(   40 /   128)	LOSS:	0.686
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.682
# VALIDATION BATCH:	(   60 /   128)	LOSS:	1.161
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.133
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.617
# VALIDATION BATCH:	(   90 /   128)	LOSS:	0.846
# VALIDATION BATCH:	(  100 /   128)	LOSS:	0.919
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.520
# VALIDATION BATCH:	(  120 /   128)	LOSS:	1.025
# EPOCH:	    6	TRAIN LOSS:	1.587	TRAIN ACCURACY:	0.544	VAL LOSS:	1.134	VAL ACCURACY:	0.662
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.095
# TRAINING BATCH:	(   10 /   512)	LOSS:	2.057
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.473
# TRAINING BATCH:	(   30 /   512)	LOSS:	1.719
# TRAINING BATCH:	(   40 /   512)	LOSS:	1.892
# TRAINING BATCH:	(   50 /   512)	LOSS:	1.732
# TRAINING BATCH:	(   60 /   512)	LOSS:	0.676
# TRAINING BATCH:	(   70 /   512)	LOSS:	0.460
# TRAINING BATCH:	(   80 /   512)	LOSS:	0.719
# TRAINING BATCH:	(   90 /   512)	LOSS:	1.383
# TRAINING BATCH:	(  100 /   512)	LOSS:	2.289
# TRAINING BATCH:	(  110 /   512)	LOSS:	1.401
# TRAINING BATCH:	(  120 /   512)	LOSS:	1.679
# TRAINING BATCH:	(  130 /   512)	LOSS:	1.676
# TRAINING BATCH:	(  140 /   512)	LOSS:	1.247
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.338
# TRAINING BATCH:	(  160 /   512)	LOSS:	1.603
# TRAINING BATCH:	(  170 /   512)	LOSS:	2.304
# TRAINING BATCH:	(  180 /   512)	LOSS:	1.270
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.849
# TRAINING BATCH:	(  200 /   512)	LOSS:	1.556
# TRAINING BATCH:	(  210 /   512)	LOSS:	1.333
# TRAINING BATCH:	(  220 /   512)	LOSS:	1.313
# TRAINING BATCH:	(  230 /   512)	LOSS:	1.698
# TRAINING BATCH:	(  240 /   512)	LOSS:	1.423
# TRAINING BATCH:	(  250 /   512)	LOSS:	2.241
# TRAINING BATCH:	(  260 /   512)	LOSS:	2.027
# TRAINING BATCH:	(  270 /   512)	LOSS:	1.575
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.387
# TRAINING BATCH:	(  290 /   512)	LOSS:	1.643
# TRAINING BATCH:	(  300 /   512)	LOSS:	1.354
# TRAINING BATCH:	(  310 /   512)	LOSS:	1.952
# TRAINING BATCH:	(  320 /   512)	LOSS:	2.050
# TRAINING BATCH:	(  330 /   512)	LOSS:	1.591
# TRAINING BATCH:	(  340 /   512)	LOSS:	1.431
# TRAINING BATCH:	(  350 /   512)	LOSS:	2.742
# TRAINING BATCH:	(  360 /   512)	LOSS:	1.762
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.372
# TRAINING BATCH:	(  380 /   512)	LOSS:	1.711
# TRAINING BATCH:	(  390 /   512)	LOSS:	1.425
# TRAINING BATCH:	(  400 /   512)	LOSS:	1.177
# TRAINING BATCH:	(  410 /   512)	LOSS:	1.411
# TRAINING BATCH:	(  420 /   512)	LOSS:	1.117
# TRAINING BATCH:	(  430 /   512)	LOSS:	1.484
# TRAINING BATCH:	(  440 /   512)	LOSS:	1.829
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.688
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.637
# TRAINING BATCH:	(  470 /   512)	LOSS:	1.353
# TRAINING BATCH:	(  480 /   512)	LOSS:	2.195
# TRAINING BATCH:	(  490 /   512)	LOSS:	1.632
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.321
# TRAINING BATCH:	(  510 /   512)	LOSS:	1.158
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.246
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.399
# VALIDATION BATCH:	(   20 /   128)	LOSS:	2.031
# VALIDATION BATCH:	(   30 /   128)	LOSS:	0.911
# VALIDATION BATCH:	(   40 /   128)	LOSS:	0.705
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.751
# VALIDATION BATCH:	(   60 /   128)	LOSS:	0.604
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.412
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.391
# VALIDATION BATCH:	(   90 /   128)	LOSS:	1.046
# VALIDATION BATCH:	(  100 /   128)	LOSS:	0.962
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.314
# VALIDATION BATCH:	(  120 /   128)	LOSS:	0.827
# EPOCH:	    7	TRAIN LOSS:	1.557	TRAIN ACCURACY:	0.548	VAL LOSS:	1.066	VAL ACCURACY:	0.685
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.505
# TRAINING BATCH:	(   10 /   512)	LOSS:	2.185
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.395
# TRAINING BATCH:	(   30 /   512)	LOSS:	1.854
# TRAINING BATCH:	(   40 /   512)	LOSS:	1.695
# TRAINING BATCH:	(   50 /   512)	LOSS:	1.072
# TRAINING BATCH:	(   60 /   512)	LOSS:	1.733
# TRAINING BATCH:	(   70 /   512)	LOSS:	1.008
# TRAINING BATCH:	(   80 /   512)	LOSS:	1.251
# TRAINING BATCH:	(   90 /   512)	LOSS:	1.462
# TRAINING BATCH:	(  100 /   512)	LOSS:	1.035
# TRAINING BATCH:	(  110 /   512)	LOSS:	1.374
# TRAINING BATCH:	(  120 /   512)	LOSS:	2.001
# TRAINING BATCH:	(  130 /   512)	LOSS:	2.587
# TRAINING BATCH:	(  140 /   512)	LOSS:	0.929
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.055
# TRAINING BATCH:	(  160 /   512)	LOSS:	1.306
# TRAINING BATCH:	(  170 /   512)	LOSS:	1.225
# TRAINING BATCH:	(  180 /   512)	LOSS:	1.625
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.477
# TRAINING BATCH:	(  200 /   512)	LOSS:	1.350
# TRAINING BATCH:	(  210 /   512)	LOSS:	0.865
# TRAINING BATCH:	(  220 /   512)	LOSS:	1.990
# TRAINING BATCH:	(  230 /   512)	LOSS:	1.445
# TRAINING BATCH:	(  240 /   512)	LOSS:	2.433
# TRAINING BATCH:	(  250 /   512)	LOSS:	1.820
# TRAINING BATCH:	(  260 /   512)	LOSS:	1.049
# TRAINING BATCH:	(  270 /   512)	LOSS:	1.753
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.891
# TRAINING BATCH:	(  290 /   512)	LOSS:	1.608
# TRAINING BATCH:	(  300 /   512)	LOSS:	1.655
# TRAINING BATCH:	(  310 /   512)	LOSS:	1.999
# TRAINING BATCH:	(  320 /   512)	LOSS:	1.594
# TRAINING BATCH:	(  330 /   512)	LOSS:	0.528
# TRAINING BATCH:	(  340 /   512)	LOSS:	0.629
# TRAINING BATCH:	(  350 /   512)	LOSS:	0.905
# TRAINING BATCH:	(  360 /   512)	LOSS:	1.400
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.167
# TRAINING BATCH:	(  380 /   512)	LOSS:	1.714
# TRAINING BATCH:	(  390 /   512)	LOSS:	2.027
# TRAINING BATCH:	(  400 /   512)	LOSS:	2.701
# TRAINING BATCH:	(  410 /   512)	LOSS:	1.767
# TRAINING BATCH:	(  420 /   512)	LOSS:	1.291
# TRAINING BATCH:	(  430 /   512)	LOSS:	1.573
# TRAINING BATCH:	(  440 /   512)	LOSS:	2.058
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.582
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.451
# TRAINING BATCH:	(  470 /   512)	LOSS:	1.552
# TRAINING BATCH:	(  480 /   512)	LOSS:	1.891
# TRAINING BATCH:	(  490 /   512)	LOSS:	0.669
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.378
# TRAINING BATCH:	(  510 /   512)	LOSS:	1.249
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.326
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.847
# VALIDATION BATCH:	(   20 /   128)	LOSS:	1.344
# VALIDATION BATCH:	(   30 /   128)	LOSS:	0.923
# VALIDATION BATCH:	(   40 /   128)	LOSS:	0.888
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.831
# VALIDATION BATCH:	(   60 /   128)	LOSS:	1.102
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.308
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.605
# VALIDATION BATCH:	(   90 /   128)	LOSS:	0.718
# VALIDATION BATCH:	(  100 /   128)	LOSS:	0.761
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.277
# VALIDATION BATCH:	(  120 /   128)	LOSS:	0.680
# EPOCH:	    8	TRAIN LOSS:	1.494	TRAIN ACCURACY:	0.569	VAL LOSS:	1.082	VAL ACCURACY:	0.675
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.807
# TRAINING BATCH:	(   10 /   512)	LOSS:	1.054
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.515
# TRAINING BATCH:	(   30 /   512)	LOSS:	1.204
# TRAINING BATCH:	(   40 /   512)	LOSS:	0.871
# TRAINING BATCH:	(   50 /   512)	LOSS:	0.989
# TRAINING BATCH:	(   60 /   512)	LOSS:	2.630
# TRAINING BATCH:	(   70 /   512)	LOSS:	1.822
# TRAINING BATCH:	(   80 /   512)	LOSS:	1.455
# TRAINING BATCH:	(   90 /   512)	LOSS:	1.615
# TRAINING BATCH:	(  100 /   512)	LOSS:	1.359
# TRAINING BATCH:	(  110 /   512)	LOSS:	1.378
# TRAINING BATCH:	(  120 /   512)	LOSS:	2.330
# TRAINING BATCH:	(  130 /   512)	LOSS:	1.130
# TRAINING BATCH:	(  140 /   512)	LOSS:	1.069
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.015
# TRAINING BATCH:	(  160 /   512)	LOSS:	1.115
# TRAINING BATCH:	(  170 /   512)	LOSS:	2.116
# TRAINING BATCH:	(  180 /   512)	LOSS:	0.639
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.817
# TRAINING BATCH:	(  200 /   512)	LOSS:	1.425
# TRAINING BATCH:	(  210 /   512)	LOSS:	1.486
# TRAINING BATCH:	(  220 /   512)	LOSS:	0.912
# TRAINING BATCH:	(  230 /   512)	LOSS:	1.361
# TRAINING BATCH:	(  240 /   512)	LOSS:	1.513
# TRAINING BATCH:	(  250 /   512)	LOSS:	0.903
# TRAINING BATCH:	(  260 /   512)	LOSS:	0.742
# TRAINING BATCH:	(  270 /   512)	LOSS:	1.671
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.635
# TRAINING BATCH:	(  290 /   512)	LOSS:	1.547
# TRAINING BATCH:	(  300 /   512)	LOSS:	0.823
# TRAINING BATCH:	(  310 /   512)	LOSS:	1.288
# TRAINING BATCH:	(  320 /   512)	LOSS:	1.202
# TRAINING BATCH:	(  330 /   512)	LOSS:	1.361
# TRAINING BATCH:	(  340 /   512)	LOSS:	1.958
# TRAINING BATCH:	(  350 /   512)	LOSS:	1.548
# TRAINING BATCH:	(  360 /   512)	LOSS:	2.264
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.689
# TRAINING BATCH:	(  380 /   512)	LOSS:	0.969
# TRAINING BATCH:	(  390 /   512)	LOSS:	1.102
# TRAINING BATCH:	(  400 /   512)	LOSS:	1.073
# TRAINING BATCH:	(  410 /   512)	LOSS:	1.880
# TRAINING BATCH:	(  420 /   512)	LOSS:	1.281
# TRAINING BATCH:	(  430 /   512)	LOSS:	1.586
# TRAINING BATCH:	(  440 /   512)	LOSS:	1.842
# TRAINING BATCH:	(  450 /   512)	LOSS:	2.011
# TRAINING BATCH:	(  460 /   512)	LOSS:	0.763
# TRAINING BATCH:	(  470 /   512)	LOSS:	0.577
# TRAINING BATCH:	(  480 /   512)	LOSS:	1.056
# TRAINING BATCH:	(  490 /   512)	LOSS:	1.175
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.109
# TRAINING BATCH:	(  510 /   512)	LOSS:	1.023
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.201
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.587
# VALIDATION BATCH:	(   20 /   128)	LOSS:	2.112
# VALIDATION BATCH:	(   30 /   128)	LOSS:	1.023
# VALIDATION BATCH:	(   40 /   128)	LOSS:	0.892
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.861
# VALIDATION BATCH:	(   60 /   128)	LOSS:	1.049
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.144
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.336
# VALIDATION BATCH:	(   90 /   128)	LOSS:	1.108
# VALIDATION BATCH:	(  100 /   128)	LOSS:	0.810
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.373
# VALIDATION BATCH:	(  120 /   128)	LOSS:	0.920
# EPOCH:	    9	TRAIN LOSS:	1.446	TRAIN ACCURACY:	0.576	VAL LOSS:	1.047	VAL ACCURACY:	0.702
# TRAINING BATCH:	(    0 /   512)	LOSS:	0.924
# TRAINING BATCH:	(   10 /   512)	LOSS:	1.603
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.335
# TRAINING BATCH:	(   30 /   512)	LOSS:	0.914
# TRAINING BATCH:	(   40 /   512)	LOSS:	1.632
# TRAINING BATCH:	(   50 /   512)	LOSS:	0.969
# TRAINING BATCH:	(   60 /   512)	LOSS:	1.443
# TRAINING BATCH:	(   70 /   512)	LOSS:	1.117
# TRAINING BATCH:	(   80 /   512)	LOSS:	1.314
# TRAINING BATCH:	(   90 /   512)	LOSS:	2.337
# TRAINING BATCH:	(  100 /   512)	LOSS:	1.565
# TRAINING BATCH:	(  110 /   512)	LOSS:	1.144
# TRAINING BATCH:	(  120 /   512)	LOSS:	0.850
# TRAINING BATCH:	(  130 /   512)	LOSS:	1.609
# TRAINING BATCH:	(  140 /   512)	LOSS:	1.117
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.448
# TRAINING BATCH:	(  160 /   512)	LOSS:	2.176
# TRAINING BATCH:	(  170 /   512)	LOSS:	1.282
# TRAINING BATCH:	(  180 /   512)	LOSS:	1.880
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.225
# TRAINING BATCH:	(  200 /   512)	LOSS:	1.475
# TRAINING BATCH:	(  210 /   512)	LOSS:	1.833
# TRAINING BATCH:	(  220 /   512)	LOSS:	1.534
# TRAINING BATCH:	(  230 /   512)	LOSS:	0.973
# TRAINING BATCH:	(  240 /   512)	LOSS:	1.102
# TRAINING BATCH:	(  250 /   512)	LOSS:	1.732
# TRAINING BATCH:	(  260 /   512)	LOSS:	0.874
# TRAINING BATCH:	(  270 /   512)	LOSS:	1.175
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.162
# TRAINING BATCH:	(  290 /   512)	LOSS:	1.638
# TRAINING BATCH:	(  300 /   512)	LOSS:	0.698
# TRAINING BATCH:	(  310 /   512)	LOSS:	1.449
# TRAINING BATCH:	(  320 /   512)	LOSS:	1.177
# TRAINING BATCH:	(  330 /   512)	LOSS:	1.159
# TRAINING BATCH:	(  340 /   512)	LOSS:	1.009
# TRAINING BATCH:	(  350 /   512)	LOSS:	1.682
# TRAINING BATCH:	(  360 /   512)	LOSS:	0.950
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.257
# TRAINING BATCH:	(  380 /   512)	LOSS:	1.868
# TRAINING BATCH:	(  390 /   512)	LOSS:	1.573
# TRAINING BATCH:	(  400 /   512)	LOSS:	1.646
# TRAINING BATCH:	(  410 /   512)	LOSS:	1.103
# TRAINING BATCH:	(  420 /   512)	LOSS:	1.212
# TRAINING BATCH:	(  430 /   512)	LOSS:	3.033
# TRAINING BATCH:	(  440 /   512)	LOSS:	2.038
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.794
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.496
# TRAINING BATCH:	(  470 /   512)	LOSS:	2.038
# TRAINING BATCH:	(  480 /   512)	LOSS:	1.000
# TRAINING BATCH:	(  490 /   512)	LOSS:	1.311
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.140
# TRAINING BATCH:	(  510 /   512)	LOSS:	1.257
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.256
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.509
# VALIDATION BATCH:	(   20 /   128)	LOSS:	1.518
# VALIDATION BATCH:	(   30 /   128)	LOSS:	1.149
# VALIDATION BATCH:	(   40 /   128)	LOSS:	0.963
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.774
# VALIDATION BATCH:	(   60 /   128)	LOSS:	1.085
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.242
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.373
# VALIDATION BATCH:	(   90 /   128)	LOSS:	0.801
# VALIDATION BATCH:	(  100 /   128)	LOSS:	0.862
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.237
# VALIDATION BATCH:	(  120 /   128)	LOSS:	0.781
# EPOCH:	   10	TRAIN LOSS:	1.419	TRAIN ACCURACY:	0.585	VAL LOSS:	1.053	VAL ACCURACY:	0.683
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.040
# TRAINING BATCH:	(   10 /   512)	LOSS:	1.628
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.171
# TRAINING BATCH:	(   30 /   512)	LOSS:	1.507
# TRAINING BATCH:	(   40 /   512)	LOSS:	1.269
# TRAINING BATCH:	(   50 /   512)	LOSS:	1.208
# TRAINING BATCH:	(   60 /   512)	LOSS:	1.595
# TRAINING BATCH:	(   70 /   512)	LOSS:	1.249
# TRAINING BATCH:	(   80 /   512)	LOSS:	0.911
# TRAINING BATCH:	(   90 /   512)	LOSS:	0.738
# TRAINING BATCH:	(  100 /   512)	LOSS:	1.388
# TRAINING BATCH:	(  110 /   512)	LOSS:	1.500
# TRAINING BATCH:	(  120 /   512)	LOSS:	0.715
# TRAINING BATCH:	(  130 /   512)	LOSS:	1.339
# TRAINING BATCH:	(  140 /   512)	LOSS:	0.835
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.986
# TRAINING BATCH:	(  160 /   512)	LOSS:	0.908
# TRAINING BATCH:	(  170 /   512)	LOSS:	1.583
# TRAINING BATCH:	(  180 /   512)	LOSS:	1.510
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.500
# TRAINING BATCH:	(  200 /   512)	LOSS:	1.197
# TRAINING BATCH:	(  210 /   512)	LOSS:	1.374
# TRAINING BATCH:	(  220 /   512)	LOSS:	2.375
# TRAINING BATCH:	(  230 /   512)	LOSS:	1.926
# TRAINING BATCH:	(  240 /   512)	LOSS:	1.207
# TRAINING BATCH:	(  250 /   512)	LOSS:	1.216
# TRAINING BATCH:	(  260 /   512)	LOSS:	1.487
# TRAINING BATCH:	(  270 /   512)	LOSS:	1.341
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.140
# TRAINING BATCH:	(  290 /   512)	LOSS:	2.257
# TRAINING BATCH:	(  300 /   512)	LOSS:	2.335
# TRAINING BATCH:	(  310 /   512)	LOSS:	1.334
# TRAINING BATCH:	(  320 /   512)	LOSS:	1.069
# TRAINING BATCH:	(  330 /   512)	LOSS:	1.334
# TRAINING BATCH:	(  340 /   512)	LOSS:	1.549
# TRAINING BATCH:	(  350 /   512)	LOSS:	1.516
# TRAINING BATCH:	(  360 /   512)	LOSS:	1.605
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.976
# TRAINING BATCH:	(  380 /   512)	LOSS:	2.300
# TRAINING BATCH:	(  390 /   512)	LOSS:	1.393
# TRAINING BATCH:	(  400 /   512)	LOSS:	1.268
# TRAINING BATCH:	(  410 /   512)	LOSS:	0.952
# TRAINING BATCH:	(  420 /   512)	LOSS:	0.967
# TRAINING BATCH:	(  430 /   512)	LOSS:	1.571
# TRAINING BATCH:	(  440 /   512)	LOSS:	1.168
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.619
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.833
# TRAINING BATCH:	(  470 /   512)	LOSS:	1.101
# TRAINING BATCH:	(  480 /   512)	LOSS:	1.729
# TRAINING BATCH:	(  490 /   512)	LOSS:	1.418
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.705
# TRAINING BATCH:	(  510 /   512)	LOSS:	1.145
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.612
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.536
# VALIDATION BATCH:	(   20 /   128)	LOSS:	1.797
# VALIDATION BATCH:	(   30 /   128)	LOSS:	0.970
# VALIDATION BATCH:	(   40 /   128)	LOSS:	1.004
# VALIDATION BATCH:	(   50 /   128)	LOSS:	1.161
# VALIDATION BATCH:	(   60 /   128)	LOSS:	1.450
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.652
# VALIDATION BATCH:	(   80 /   128)	LOSS:	1.101
# VALIDATION BATCH:	(   90 /   128)	LOSS:	0.797
# VALIDATION BATCH:	(  100 /   128)	LOSS:	0.925
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.384
# VALIDATION BATCH:	(  120 /   128)	LOSS:	1.208
# EPOCH:	   11	TRAIN LOSS:	1.365	TRAIN ACCURACY:	0.606	VAL LOSS:	1.129	VAL ACCURACY:	0.686
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.309
# TRAINING BATCH:	(   10 /   512)	LOSS:	0.995
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.451
# TRAINING BATCH:	(   30 /   512)	LOSS:	1.582
# TRAINING BATCH:	(   40 /   512)	LOSS:	1.576
# TRAINING BATCH:	(   50 /   512)	LOSS:	1.740
# TRAINING BATCH:	(   60 /   512)	LOSS:	0.905
# TRAINING BATCH:	(   70 /   512)	LOSS:	0.861
# TRAINING BATCH:	(   80 /   512)	LOSS:	1.162
# TRAINING BATCH:	(   90 /   512)	LOSS:	2.375
# TRAINING BATCH:	(  100 /   512)	LOSS:	1.369
# TRAINING BATCH:	(  110 /   512)	LOSS:	1.709
# TRAINING BATCH:	(  120 /   512)	LOSS:	1.242
# TRAINING BATCH:	(  130 /   512)	LOSS:	1.286
# TRAINING BATCH:	(  140 /   512)	LOSS:	1.407
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.717
# TRAINING BATCH:	(  160 /   512)	LOSS:	1.600
# TRAINING BATCH:	(  170 /   512)	LOSS:	1.064
# TRAINING BATCH:	(  180 /   512)	LOSS:	1.276
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.212
# TRAINING BATCH:	(  200 /   512)	LOSS:	2.141
# TRAINING BATCH:	(  210 /   512)	LOSS:	0.914
# TRAINING BATCH:	(  220 /   512)	LOSS:	1.092
# TRAINING BATCH:	(  230 /   512)	LOSS:	1.004
# TRAINING BATCH:	(  240 /   512)	LOSS:	1.068
# TRAINING BATCH:	(  250 /   512)	LOSS:	1.471
# TRAINING BATCH:	(  260 /   512)	LOSS:	1.470
# TRAINING BATCH:	(  270 /   512)	LOSS:	0.796
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.426
# TRAINING BATCH:	(  290 /   512)	LOSS:	1.120
# TRAINING BATCH:	(  300 /   512)	LOSS:	2.006
# TRAINING BATCH:	(  310 /   512)	LOSS:	0.670
# TRAINING BATCH:	(  320 /   512)	LOSS:	1.218
# TRAINING BATCH:	(  330 /   512)	LOSS:	1.934
# TRAINING BATCH:	(  340 /   512)	LOSS:	1.382
# TRAINING BATCH:	(  350 /   512)	LOSS:	1.372
# TRAINING BATCH:	(  360 /   512)	LOSS:	1.599
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.387
# TRAINING BATCH:	(  380 /   512)	LOSS:	1.325
# TRAINING BATCH:	(  390 /   512)	LOSS:	1.738
# TRAINING BATCH:	(  400 /   512)	LOSS:	1.387
# TRAINING BATCH:	(  410 /   512)	LOSS:	1.148
# TRAINING BATCH:	(  420 /   512)	LOSS:	0.778
# TRAINING BATCH:	(  430 /   512)	LOSS:	1.022
# TRAINING BATCH:	(  440 /   512)	LOSS:	1.557
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.077
# TRAINING BATCH:	(  460 /   512)	LOSS:	0.786
# TRAINING BATCH:	(  470 /   512)	LOSS:	1.243
# TRAINING BATCH:	(  480 /   512)	LOSS:	1.668
# TRAINING BATCH:	(  490 /   512)	LOSS:	1.284
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.238
# TRAINING BATCH:	(  510 /   512)	LOSS:	1.760
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.250
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.437
# VALIDATION BATCH:	(   20 /   128)	LOSS:	2.013
# VALIDATION BATCH:	(   30 /   128)	LOSS:	0.791
# VALIDATION BATCH:	(   40 /   128)	LOSS:	1.037
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.662
# VALIDATION BATCH:	(   60 /   128)	LOSS:	0.768
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.494
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.485
# VALIDATION BATCH:	(   90 /   128)	LOSS:	0.341
# VALIDATION BATCH:	(  100 /   128)	LOSS:	1.234
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.299
# VALIDATION BATCH:	(  120 /   128)	LOSS:	1.306
# EPOCH:	   12	TRAIN LOSS:	1.354	TRAIN ACCURACY:	0.601	VAL LOSS:	1.070	VAL ACCURACY:	0.702
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.065
# TRAINING BATCH:	(   10 /   512)	LOSS:	1.114
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.835
# TRAINING BATCH:	(   30 /   512)	LOSS:	1.151
# TRAINING BATCH:	(   40 /   512)	LOSS:	1.749
# TRAINING BATCH:	(   50 /   512)	LOSS:	1.321
# TRAINING BATCH:	(   60 /   512)	LOSS:	0.766
# TRAINING BATCH:	(   70 /   512)	LOSS:	0.902
# TRAINING BATCH:	(   80 /   512)	LOSS:	1.001
# TRAINING BATCH:	(   90 /   512)	LOSS:	1.532
# TRAINING BATCH:	(  100 /   512)	LOSS:	1.174
# TRAINING BATCH:	(  110 /   512)	LOSS:	1.353
# TRAINING BATCH:	(  120 /   512)	LOSS:	0.998
# TRAINING BATCH:	(  130 /   512)	LOSS:	1.445
# TRAINING BATCH:	(  140 /   512)	LOSS:	2.095
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.323
# TRAINING BATCH:	(  160 /   512)	LOSS:	1.710
# TRAINING BATCH:	(  170 /   512)	LOSS:	1.135
# TRAINING BATCH:	(  180 /   512)	LOSS:	1.773
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.452
# TRAINING BATCH:	(  200 /   512)	LOSS:	1.746
# TRAINING BATCH:	(  210 /   512)	LOSS:	1.566
# TRAINING BATCH:	(  220 /   512)	LOSS:	0.951
# TRAINING BATCH:	(  230 /   512)	LOSS:	0.832
# TRAINING BATCH:	(  240 /   512)	LOSS:	1.411
# TRAINING BATCH:	(  250 /   512)	LOSS:	1.064
# TRAINING BATCH:	(  260 /   512)	LOSS:	1.385
# TRAINING BATCH:	(  270 /   512)	LOSS:	1.283
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.056
# TRAINING BATCH:	(  290 /   512)	LOSS:	1.219
# TRAINING BATCH:	(  300 /   512)	LOSS:	0.759
# TRAINING BATCH:	(  310 /   512)	LOSS:	1.334
# TRAINING BATCH:	(  320 /   512)	LOSS:	2.591
# TRAINING BATCH:	(  330 /   512)	LOSS:	1.229
# TRAINING BATCH:	(  340 /   512)	LOSS:	1.175
# TRAINING BATCH:	(  350 /   512)	LOSS:	1.482
# TRAINING BATCH:	(  360 /   512)	LOSS:	0.807
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.413
# TRAINING BATCH:	(  380 /   512)	LOSS:	0.955
# TRAINING BATCH:	(  390 /   512)	LOSS:	1.511
# TRAINING BATCH:	(  400 /   512)	LOSS:	1.094
# TRAINING BATCH:	(  410 /   512)	LOSS:	1.940
# TRAINING BATCH:	(  420 /   512)	LOSS:	1.256
# TRAINING BATCH:	(  430 /   512)	LOSS:	1.366
# TRAINING BATCH:	(  440 /   512)	LOSS:	1.869
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.325
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.122
# TRAINING BATCH:	(  470 /   512)	LOSS:	1.215
# TRAINING BATCH:	(  480 /   512)	LOSS:	2.197
# TRAINING BATCH:	(  490 /   512)	LOSS:	1.585
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.596
# TRAINING BATCH:	(  510 /   512)	LOSS:	1.271
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.507
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.516
# VALIDATION BATCH:	(   20 /   128)	LOSS:	1.914
# VALIDATION BATCH:	(   30 /   128)	LOSS:	0.861
# VALIDATION BATCH:	(   40 /   128)	LOSS:	0.922
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.774
# VALIDATION BATCH:	(   60 /   128)	LOSS:	0.801
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.499
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.390
# VALIDATION BATCH:	(   90 /   128)	LOSS:	1.048
# VALIDATION BATCH:	(  100 /   128)	LOSS:	1.079
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.227
# VALIDATION BATCH:	(  120 /   128)	LOSS:	0.983
# EPOCH:	   13	TRAIN LOSS:	1.305	TRAIN ACCURACY:	0.618	VAL LOSS:	1.073	VAL ACCURACY:	0.697
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.453
# TRAINING BATCH:	(   10 /   512)	LOSS:	1.747
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.158
# TRAINING BATCH:	(   30 /   512)	LOSS:	1.554
# TRAINING BATCH:	(   40 /   512)	LOSS:	1.611
# TRAINING BATCH:	(   50 /   512)	LOSS:	0.598
# TRAINING BATCH:	(   60 /   512)	LOSS:	1.743
# TRAINING BATCH:	(   70 /   512)	LOSS:	1.432
# TRAINING BATCH:	(   80 /   512)	LOSS:	1.552
# TRAINING BATCH:	(   90 /   512)	LOSS:	0.891
# TRAINING BATCH:	(  100 /   512)	LOSS:	1.041
# TRAINING BATCH:	(  110 /   512)	LOSS:	1.044
# TRAINING BATCH:	(  120 /   512)	LOSS:	1.293
# TRAINING BATCH:	(  130 /   512)	LOSS:	1.177
# TRAINING BATCH:	(  140 /   512)	LOSS:	1.112
# TRAINING BATCH:	(  150 /   512)	LOSS:	0.798
# TRAINING BATCH:	(  160 /   512)	LOSS:	1.240
# TRAINING BATCH:	(  170 /   512)	LOSS:	0.896
# TRAINING BATCH:	(  180 /   512)	LOSS:	0.962
# TRAINING BATCH:	(  190 /   512)	LOSS:	0.862
# TRAINING BATCH:	(  200 /   512)	LOSS:	0.969
# TRAINING BATCH:	(  210 /   512)	LOSS:	1.161
# TRAINING BATCH:	(  220 /   512)	LOSS:	1.675
# TRAINING BATCH:	(  230 /   512)	LOSS:	0.398
# TRAINING BATCH:	(  240 /   512)	LOSS:	0.840
# TRAINING BATCH:	(  250 /   512)	LOSS:	1.420
# TRAINING BATCH:	(  260 /   512)	LOSS:	0.751
# TRAINING BATCH:	(  270 /   512)	LOSS:	0.901
# TRAINING BATCH:	(  280 /   512)	LOSS:	2.177
# TRAINING BATCH:	(  290 /   512)	LOSS:	1.544
# TRAINING BATCH:	(  300 /   512)	LOSS:	0.827
# TRAINING BATCH:	(  310 /   512)	LOSS:	1.116
# TRAINING BATCH:	(  320 /   512)	LOSS:	1.286
# TRAINING BATCH:	(  330 /   512)	LOSS:	1.771
# TRAINING BATCH:	(  340 /   512)	LOSS:	1.230
# TRAINING BATCH:	(  350 /   512)	LOSS:	1.666
# TRAINING BATCH:	(  360 /   512)	LOSS:	0.893
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.341
# TRAINING BATCH:	(  380 /   512)	LOSS:	0.906
# TRAINING BATCH:	(  390 /   512)	LOSS:	2.054
# TRAINING BATCH:	(  400 /   512)	LOSS:	1.461
# TRAINING BATCH:	(  410 /   512)	LOSS:	1.716
# TRAINING BATCH:	(  420 /   512)	LOSS:	1.363
# TRAINING BATCH:	(  430 /   512)	LOSS:	1.416
# TRAINING BATCH:	(  440 /   512)	LOSS:	1.576
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.305
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.507
# TRAINING BATCH:	(  470 /   512)	LOSS:	1.837
# TRAINING BATCH:	(  480 /   512)	LOSS:	1.523
# TRAINING BATCH:	(  490 /   512)	LOSS:	0.991
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.250
# TRAINING BATCH:	(  510 /   512)	LOSS:	1.167
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.620
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.279
# VALIDATION BATCH:	(   20 /   128)	LOSS:	1.642
# VALIDATION BATCH:	(   30 /   128)	LOSS:	1.454
# VALIDATION BATCH:	(   40 /   128)	LOSS:	1.039
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.719
# VALIDATION BATCH:	(   60 /   128)	LOSS:	0.720
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.441
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.759
# VALIDATION BATCH:	(   90 /   128)	LOSS:	1.151
# VALIDATION BATCH:	(  100 /   128)	LOSS:	1.250
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.330
# VALIDATION BATCH:	(  120 /   128)	LOSS:	0.917
# EPOCH:	   14	TRAIN LOSS:	1.261	TRAIN ACCURACY:	0.626	VAL LOSS:	1.129	VAL ACCURACY:	0.697
# TRAINING BATCH:	(    0 /   512)	LOSS:	1.835
# TRAINING BATCH:	(   10 /   512)	LOSS:	2.036
# TRAINING BATCH:	(   20 /   512)	LOSS:	1.665
# TRAINING BATCH:	(   30 /   512)	LOSS:	1.350
# TRAINING BATCH:	(   40 /   512)	LOSS:	1.388
# TRAINING BATCH:	(   50 /   512)	LOSS:	1.113
# TRAINING BATCH:	(   60 /   512)	LOSS:	1.020
# TRAINING BATCH:	(   70 /   512)	LOSS:	1.417
# TRAINING BATCH:	(   80 /   512)	LOSS:	0.418
# TRAINING BATCH:	(   90 /   512)	LOSS:	1.009
# TRAINING BATCH:	(  100 /   512)	LOSS:	0.884
# TRAINING BATCH:	(  110 /   512)	LOSS:	1.786
# TRAINING BATCH:	(  120 /   512)	LOSS:	1.089
# TRAINING BATCH:	(  130 /   512)	LOSS:	1.435
# TRAINING BATCH:	(  140 /   512)	LOSS:	1.472
# TRAINING BATCH:	(  150 /   512)	LOSS:	1.571
# TRAINING BATCH:	(  160 /   512)	LOSS:	0.508
# TRAINING BATCH:	(  170 /   512)	LOSS:	2.371
# TRAINING BATCH:	(  180 /   512)	LOSS:	1.527
# TRAINING BATCH:	(  190 /   512)	LOSS:	1.166
# TRAINING BATCH:	(  200 /   512)	LOSS:	1.405
# TRAINING BATCH:	(  210 /   512)	LOSS:	0.615
# TRAINING BATCH:	(  220 /   512)	LOSS:	1.388
# TRAINING BATCH:	(  230 /   512)	LOSS:	0.813
# TRAINING BATCH:	(  240 /   512)	LOSS:	0.890
# TRAINING BATCH:	(  250 /   512)	LOSS:	2.084
# TRAINING BATCH:	(  260 /   512)	LOSS:	1.752
# TRAINING BATCH:	(  270 /   512)	LOSS:	1.528
# TRAINING BATCH:	(  280 /   512)	LOSS:	1.601
# TRAINING BATCH:	(  290 /   512)	LOSS:	1.540
# TRAINING BATCH:	(  300 /   512)	LOSS:	0.792
# TRAINING BATCH:	(  310 /   512)	LOSS:	1.258
# TRAINING BATCH:	(  320 /   512)	LOSS:	1.740
# TRAINING BATCH:	(  330 /   512)	LOSS:	1.258
# TRAINING BATCH:	(  340 /   512)	LOSS:	0.945
# TRAINING BATCH:	(  350 /   512)	LOSS:	1.023
# TRAINING BATCH:	(  360 /   512)	LOSS:	1.485
# TRAINING BATCH:	(  370 /   512)	LOSS:	1.440
# TRAINING BATCH:	(  380 /   512)	LOSS:	1.240
# TRAINING BATCH:	(  390 /   512)	LOSS:	1.543
# TRAINING BATCH:	(  400 /   512)	LOSS:	1.047
# TRAINING BATCH:	(  410 /   512)	LOSS:	1.155
# TRAINING BATCH:	(  420 /   512)	LOSS:	1.417
# TRAINING BATCH:	(  430 /   512)	LOSS:	0.821
# TRAINING BATCH:	(  440 /   512)	LOSS:	0.940
# TRAINING BATCH:	(  450 /   512)	LOSS:	1.489
# TRAINING BATCH:	(  460 /   512)	LOSS:	1.430
# TRAINING BATCH:	(  470 /   512)	LOSS:	0.644
# TRAINING BATCH:	(  480 /   512)	LOSS:	1.108
# TRAINING BATCH:	(  490 /   512)	LOSS:	1.644
# TRAINING BATCH:	(  500 /   512)	LOSS:	1.203
# TRAINING BATCH:	(  510 /   512)	LOSS:	0.648
# VALIDATION BATCH:	(    0 /   128)	LOSS:	1.575
# VALIDATION BATCH:	(   10 /   128)	LOSS:	0.469
# VALIDATION BATCH:	(   20 /   128)	LOSS:	1.395
# VALIDATION BATCH:	(   30 /   128)	LOSS:	1.284
# VALIDATION BATCH:	(   40 /   128)	LOSS:	0.918
# VALIDATION BATCH:	(   50 /   128)	LOSS:	0.748
# VALIDATION BATCH:	(   60 /   128)	LOSS:	0.891
# VALIDATION BATCH:	(   70 /   128)	LOSS:	1.374
# VALIDATION BATCH:	(   80 /   128)	LOSS:	0.693
# VALIDATION BATCH:	(   90 /   128)	LOSS:	0.896
# VALIDATION BATCH:	(  100 /   128)	LOSS:	0.944
# VALIDATION BATCH:	(  110 /   128)	LOSS:	0.347
# VALIDATION BATCH:	(  120 /   128)	LOSS:	1.179
# EPOCH:	   15	TRAIN LOSS:	1.258	TRAIN ACCURACY:	0.628	VAL LOSS:	1.100	VAL ACCURACY:	0.690

# %%
get_training_progress_plot(
    metrics['train_loss'],
    metrics['train_acc'],
    metrics['val_loss'],
    metrics['val_acc'],
)

# %% [markdown]
# As you can see, the results are much better now, and would keep improving if we had
# trained for longer.
#
#
# ## Exercise 2
# This exercise is about the receptive field of convolutional neural networks.
# For our purposes, the receptive field of a neuron in layer $L$ contains the features
# in a preceding layer $\ell$ that affect the output of said neuron, with $\ell=0$ being
# the input to the network. In other words, changing any value in a neuron's receptive
# field will change the output of that neuron. By going backwards from layer $L$,
# convolutions and pooling operations enlarge the receptive field of neurons at layer
# $L$, so that the deeper the network, the larger the receptive field of neurons at the
# end ofthe network.
#
# Let $\textbf{z}_\ell\in\mathbb{R}^{n_\ell}$ be the output of layer $\ell$
# (and $\textbf{z}_0$ the input), that is obtained with a one-dimensional convolution or
# pooling operation from $\textbf{z}_{\ell-1}$ with a kernel of size $k_\ell$ and stride
# $s_\ell$. Define $r_\ell$ to be the size of the receptive field in the $\ell$-th layer
# of a neuron in layer $L$, i.e. the minimum width of the largest region that contains
# the elements in $\textbf{z}_\ell$ that affect a generic element in $\textbf{z}_L$.
# Note that this region can contain gaps, i.e. neurons that do not affect the output of
# the neuron in layer $L$, if they are in between neurons that do affect it.
#
# **(a)** Show that $r_{\ell-1}$ can be computed from $r_\ell$ as follows:
#
# \begin{equation}
# r_{\ell-1}=s_\ell\cdot r_\ell+k_\ell-s_\ell
# \end{equation}
# You can consider padding to be infinite, or, equivalently, focus on the neurons in the
# middle of the layer, without analyzing what happens near the borders.
# Hint: consider the case $k_\ell=1$ first.
#
# Then solve the recurrence to show that:
#
# \begin{equation}
# r_0=\sum_{\ell=1}^L\left(
# \left(k_\ell-1\right)\prod_{i=1}^{\ell-1}s_i
# \right)+1
# \end{equation}
#
# with the base case being $r_L=1$.
#
# **(b)** Compute the receptive field size of the pre-trained VGG16 architecture we used above,
# right before the global average pooling layer.
#
# **(c)** Now suppose to have a dilation of $d_\ell\geq 1$ at every layer. What is the new formula
# for $r_0$?
#
# **(d)** What is the most effective way to increase the size of the receptive field of a neural
# network?
#
# #### Solution
#
# **(a)**
#
# Start with $k_\ell=1$. Every neuron in $r_\ell$, has a receptive field of 1, and we need
# to add $s_\ell-1$ for the gap left between adjacent neurons, resulting in $r_{\ell-1}=r_\ell+(r_\ell-1)(s_\ell-1)=r_\ell s_\ell-s_\ell+1$. If $k_\ell>1$ and odd, we need to add $(k_\ell-1)/2$ at both sides of the receptive field, resulting in
#
# \begin{equation}
# r_{\ell-1}=r_\ell s_\ell-s_\ell+1+2\cdot\frac{k_\ell-1}{2}=r_\ell s_\ell+k_\ell-s_\ell
# \end{equation}
# When $k_\ell$ is even, we need to add $k_\ell/2$ on one side, and $k_\ell/2-1$ on the
# other side; as this adds up to $k_\ell-1$ again, the result is the same.
#
# To solve the recurrence, we can unroll a few steps and try to spot a pattern. For ease
# of notation, we use $r,r',r'',r''',\ldots$ instead of $r_{\ell},r_{\ell-1},r_{\ell-2},r_{\ell-3},\ldots$,
# similarly for $k_\ell$ and $s_\ell$.
#
# \begin{align*}
# r' &= sr+k-s \\
# r''
#   &= s'r'+k'-s' \\
#   &= s'sr+s'k-s's+k'-s' \\
# r'''
#   &= s''r''+k''-s'' \\
#   &= s''s'sr + s''s'k - s''s's + s''k' - s''s' + k'' - s'' \\
#   &= (r-1)s''s's+(k-1)s''s'+(k'-1)s''+k'' \\
# r''''
#   &= s'''r'''+k'''-s''' \\
#   &= (r-1)s'''s''s's+(k-1)s'''s''s'+(k'-1)s'''s''+(k''-1)s''' +k'''
# \end{align*}
#
# The next element would be:
#
# \begin{align*}
# r_{\ell-5}
# &= (r_{\ell}-1)s_{\ell-4}s_{\ell-3}s_{\ell-2}s_{\ell-1}s_{\ell} \\
# &\quad+(k_{\ell}-1)s_{\ell-4}s_{\ell-3}s_{\ell-2}s_{\ell-1} \\
# &\quad+(k_{\ell-1}-1)s_{\ell-4}s_{\ell-3}s_{\ell-2} \\
# &\quad+(k_{\ell-2}-1)s_{\ell-4}s_{\ell-3} \\
# &\quad+(k_{\ell-3}-1)s_{\ell-4} \\
# &\quad+(k_{\ell-4}-1) \\
# &\quad+1
# \end{align*}
#
# The pattern should be clear:
#
# \begin{equation}
# r_{\ell-i}=
# (r_\ell-1)\prod_{j=1}^{i} s_{\ell-i+j}
# +\sum_{j=1}^{i}\left(
#   (k_{\ell-i+j}-1)\prod_{k=1}^{j-1} s_{\ell-i+k}
# \right)+1
# \end{equation}
#
# With the convention that $\prod_{i=a}^b x_i=1$ when $a>b$.
# Now using $i=\ell=L$, and remembering that $r_L=1$, we find that:
#
#
# \begin{equation}
# r_0=\sum_{j=1}^{L}\left((k_j-1)\prod_{k=1}^{j-1} s_k \right)+1
# \end{equation}
#
# **(b)** The pre-trained VGG16 has five blocks composed by two (first two blocks) or three
# (last three blocks) convolutions with kernel size 3 and stride 1 followed by a
# max pooling of kernel size 2 with stride 2. We can easily apply the recursive formula:

# %%
strides = [1,1,2, 1,1,2, 1,1,1,2, 1,1,1,2, 1,1,1,2]
kernels = [3,3,2, 3,3,2, 3,3,3,2, 3,3,3,2, 3,3,3,2]

def calc_receptive_field(r: int, l: int, kernels: list[int], strides: list[int]) -> int:
    return strides[l] * r + kernels[l] - strides[l]

func = partial(calc_receptive_field, kernels=kernels, strides=strides)
print(reduce(func, range(len(strides))))
# Out:
# 212

# %% [markdown]
# **(c)** Dilation can be seen as further gaps between the elements of every filter, so that a
# dilation of $d_j\geq 1$ leaves $d_j-1$ gaps between elements of the filter. For example,
#  a dilation of 2 means that a filter of size 3 will cover 5 elements in total, a
#  dilation of 3 results in 7 elements, and so on. With this insight, we can replace
#  $k_j$ with $k_jd_j-d_j+1$ in the formula above:
#
# \begin{equation}
# r_0=\sum_{j=1}^{L}\left((k_jd_j-d_j)\prod_{k=1}^j s_k \right)+1
# \end{equation}
#
# **(d)** According to the formula, the best way to increase the size of the receptive field of a
# network is to increase striding, because strides of successive layers get multiplied
# together. Note, however, that high strides means that, in practice, there will be large
# gaps in the receptive field, with many neurons not actually contributing to the neurons
# in the following layers. For this reason, neural networks since VGG16 have also become
# much deeper. Moreover, the receptive field is not the only parameter that affects
# performance, and having a large receptive field seems to be a necessary, but not
# sufficient condition for well-performing networks.
